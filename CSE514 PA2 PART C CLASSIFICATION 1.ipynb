# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the data
file_path = '../student-mat.csv'
data = pd.read_csv(file_path, delimiter=';')

# %%
# Binary classification problem 1: Predicting high/low grade based on median G3 value
median_g3 = data['G3'].median()
data['high_performance'] = (data['G3'] > median_g3).astype(int)

X = data.drop('high_performance', axis=1)
y = data['high_performance']

# Split dataset into training set and validation set (adjust test_size and random_state as needed)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
print("Training set shape:", X_train.shape, y_train.shape)
print("Validation set shape:", X_val.shape, y_val.shape)

train_data = pd.concat([X_train, y_train], axis=1)
train_data.to_csv('train_data_problem1.csv', index=False)

# Save validation set
val_data = pd.concat([X_val, y_val], axis=1)
val_data.to_csv('val_data_problem1.csv', index=False)
# Out:
# Training set shape: (355, 33) (355,)
# Validation set shape: (40, 33) (40,)

# %%
data = pd.read_csv(file_path, delimiter=';')

# One-hot encoding for categorical variables except for our binary targets
features = pd.get_dummies(data.drop(['G3', 'school', 'internet'], axis=1))
# Binary classification problem 2: Predicting school (already binary, just encode directly)
data['school_binary'] = (data['school'] == 'GP').astype(int)

X = data.drop('school_binary', axis=1)
y = data['school_binary']

# Split dataset into training set and validation set (adjust test_size and random_state as needed)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
print("Training set shape:", X_train.shape, y_train.shape)
print("Validation set shape:", X_val.shape, y_val.shape)

train_data = pd.concat([X_train, y_train], axis=1)
train_data.to_csv('train_data_problem2.csv', index=False)

# Save validation set
val_data = pd.concat([X_val, y_val], axis=1)
val_data.to_csv('val_data_problem2.csv', index=False)
# Out:
# Training set shape: (355, 33) (355,)
# Validation set shape: (40, 33) (40,)

# %%
 # Binary classification problem 3: Predicting internet access
data['internet_binary'] = (data['internet'] == 'yes').astype(int)
# One-hot encoding for categorical variables except for our binary targets
features = pd.get_dummies(data.drop(['G3', 'school', 'internet'], axis=1))


X = data.drop('internet_binary', axis=1)
y = data['internet_binary']

# Split dataset into training set and validation set (adjust test_size and random_state as needed)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
print("Training set shape:", X_train.shape, y_train.shape)
print("Validation set shape:", X_val.shape, y_val.shape)

train_data = pd.concat([X_train, y_train], axis=1)
train_data.to_csv('train_data_problem3.csv', index=False)

# Save validation set
val_data = pd.concat([X_val, y_val], axis=1)
val_data.to_csv('val_data_problem3.csv', index=False)
# Out:
# Training set shape: (355, 34) (355,)
# Validation set shape: (40, 34) (40,)

# %%
# Ridge Regression

import pandas as pd
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge

# Load the dataset
file_path = './train_data_problem1.csv'
data = pd.read_csv(file_path, delimiter=',')
print(data.head())
# # One-hot encoding for categorical variables except for our binary targets
# features = pd.get_dummies(data.drop(['G3', 'school', 'internet'], axis=1))

# # Binary classification problem 1: Predicting high/low grade based on median G3 value
median_g3 = data['G3'].median()
data['high_performance'] = (data['G3'] > median_g3).astype(int)

# Drop 'G1' and 'G2' columns
# data = data.drop(['G1', 'G2'], axis=1)

# # Separate the features and the target variable
# X = data.drop('G3', axis=1)
# y = data['G3']
X = data.drop('high_performance', axis=1)
y = data['high_performance']

# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating the Ridge regression model pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('ridge_regression', Ridge())
])

# Setting up parameter grid for hyperparameter tuning
param_grid = {'ridge_regression__alpha': [0.01, 0.1, 1, 10, 100]}  # alpha is equivalent to λ

# Setting up GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   15       R     GT3       T     1     1     other     other
# 1     GP   F   15       U     GT3       T     1     1     other  services
# 2     GP   F   17       U     GT3       T     4     4   teacher   teacher
# 3     GP   M   16       U     LE3       T     2     2  services  services
# 4     GP   M   16       R     GT3       T     2     2   at_home     other
#
#    ... freetime goout  Dalc  Walc  health absences  G1  G2  G3  \
# 0  ...        3     4     2     4       5        2   8   6   5
# 1  ...        4     2     1     2       5        0   8  11  11
# 2  ...        3     3     1     2       4        4  14  14  14
# 3  ...        3     3     2     2       2        8   9   9   9
# 4  ...        2     2     1     2       3        2  17  15  15
#
#   high_performance
# 0                0
# 1                0
# 2                1
# 3                0
# 4                1
#
# [5 rows x 34 columns]
# Best parameters: {'ridge_regression__alpha': 100}
# Best cross-validation score: -0.09528063445998051

# %%
# SVR
from sklearn.svm import SVR  # Using SVR for regression

# Load the dataset with the correct delimiter
data = pd.read_csv('./train_data_problem1.csv', delimiter=',')


# Separate the features and the target variable
X = data.drop('high_performance', axis=1)
y = data['high_performance']

# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating the SVM model pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('svm', SVR(C=1.0))
])

# Setting up parameter grid for hyperparameter tuning (C values to test)
param_grid = {'svm__C': [0.1, 1, 10, 100, 1000]}

# Setting up GridSearchCV for 5-fold cross-validation and hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'svm__C': 10}
# Best cross-validation score: -0.06746383535894794

# %%
# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
# Load the dataset
data = pd.read_csv('./train_data_problem1.csv', delimiter=',')


# Separate the features and the target variable
X = data.drop('high_performance', axis=1)
y = data['high_performance']


# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating the model pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('random_forest', RandomForestRegressor())
])

# Define the parameter grid to test different hyperparameter values
param_grid = {
    'random_forest__n_estimators': [10, 50, 100, 200, 500]
}

# Setting Up GridSearchCV to find the best model configuration using 5-fold cross-validation
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'random_forest__n_estimators': 10}
# Best cross-validation score: 0.0

# %%
# KNN
from sklearn.neighbors import KNeighborsRegressor 

# Load the dataset
data = pd.read_csv('./train_data_problem1.csv', delimiter=',')

X = data.drop('high_performance', axis=1)
y = data['high_performance']

# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating a modeling pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('knn', KNeighborsRegressor())
])

# Define the parameter grid to test different values for n_neighbors
param_grid = {'knn__n_neighbors': [1, 3, 5, 7, 9]}

# Setting up GridSearchCV for 5-fold cross-validation and hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'knn__n_neighbors': 5}
# Best cross-validation score: -0.045746478873239446

# %%
# ANN
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import OneHotEncoder, StandardScaler


# Load the dataset
data = pd.read_csv('./train_data_problem1.csv', delimiter=',')

X = data.drop('high_performance', axis=1)
y = data['high_performance']


# Identifying categorical columns and numerical columns for preprocessing
categorical_columns = X.select_dtypes(include=['object', 'category']).columns
numerical_columns = X.select_dtypes(include=['int', 'float']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns),
        ('scaler', StandardScaler(), numerical_columns)
    ],
    remainder='passthrough'
)

model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('ann', MLPRegressor(random_state=42, max_iter=1000, verbose=True, early_stopping=True))
])

# Define the parameter grid to test different learning rates
param_grid = {
    'ann__learning_rate_init': [0.1, 0.01, 0.001]
}

# Setting up GridSearchCV for 5-fold cross-validation and hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

# Printing the best cross-validation score
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Iteration 1, loss = 34.59978252
# Validation score: -95.403618
# Iteration 2, loss = 6.87275686
# Validation score: -1.035071
# Iteration 3, loss = 0.30168539
# Validation score: -1.588643
# Iteration 4, loss = 0.35781860
# Validation score: -1.822205
# Iteration 5, loss = 0.38992863
# Validation score: -1.996557
# Iteration 6, loss = 0.41380249
# Validation score: -2.121018
# Iteration 7, loss = 0.42620299
# Validation score: -2.181052
# Iteration 8, loss = 0.43025828
# Validation score: -2.174551
# Iteration 9, loss = 0.42822588
# Validation score: -2.135412
# Iteration 10, loss = 0.42020528
# Validation score: -2.112734
# Iteration 11, loss = 0.40762790
# Validation score: -2.101732
# Iteration 12, loss = 0.39450820
# Validation score: -1.873714
# Iteration 13, loss = 0.37532651
# Validation score: -1.636317
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 35.08972447
# Validation score: -70.702310
# Iteration 2, loss = 7.15038667
# Validation score: -1.148541
# Iteration 3, loss = 0.30026659
# Validation score: -1.554605
# Iteration 4, loss = 0.35218465
# Validation score: -1.843998
# Iteration 5, loss = 0.34830084
# Validation score: -2.433008
# Iteration 6, loss = 0.31819073
# Validation score: -3.924448
# Iteration 7, loss = 0.38093436
# Validation score: -2.212783
# Iteration 8, loss = 0.27229739
# Validation score: -0.852771
# Iteration 9, loss = 0.20724722
# Validation score: -0.543079
# Iteration 10, loss = 0.17048904
# Validation score: 0.176900
# Iteration 11, loss = 0.09360496
# Validation score: 0.334439
# Iteration 12, loss = 0.11740681
# Validation score: 0.500484
# Iteration 13, loss = 0.06613824
# Validation score: -0.000452
# Iteration 14, loss = 0.10057671
# Validation score: 0.582862
# Iteration 15, loss = 0.06582924
# Validation score: 0.440086
# Iteration 16, loss = 0.08971217
# Validation score: 0.352191
# Iteration 17, loss = 0.06964017
# Validation score: 0.266900
# Iteration 18, loss = 0.06680429
# Validation score: 0.589119
# Iteration 19, loss = 0.06345563
# Validation score: 0.595825
# Iteration 20, loss = 0.05735490
# Validation score: 0.395099
# Iteration 21, loss = 0.05868557
# Validation score: 0.501249
# Iteration 22, loss = 0.04578069
# Validation score: 0.603609
# Iteration 23, loss = 0.05909567
# Validation score: 0.577808
# Iteration 24, loss = 0.04234902
# Validation score: 0.255588
# Iteration 25, loss = 0.06570738
# Validation score: 0.513550
# Iteration 26, loss = 0.04333600
# Validation score: 0.598589
# Iteration 27, loss = 0.05792988
# Validation score: 0.570430
# Iteration 28, loss = 0.04017924
# Validation score: 0.340327
# Iteration 29, loss = 0.05271077
# Validation score: 0.491254
# Iteration 30, loss = 0.04132026
# Validation score: 0.593891
# Iteration 31, loss = 0.04521223
# Validation score: 0.552542
# Iteration 32, loss = 0.03956961
# Validation score: 0.426137
# Iteration 33, loss = 0.04273568
# Validation score: 0.486717
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss =
# Validation score: 0.455282
# Iteration 34, loss = 0.02118996
# Validation score: 0.460317
# Iteration 35, loss = 0.02060400
# Validation score: 0.465273
# Iteration 36, loss = 0.02005379
# Validation score: 0.469212
# Iteration 37, loss = 0.01948804
# Validation score: 0.471895
# Iteration 38, loss = 0.01896648
# Validation score: 0.473641
# Iteration 39, loss = 0.01850143
# Validation score: 0.474766
# Iteration 40, loss = 0.01797633
# Validation score: 0.475448
# Iteration 41, loss = 0.01747825
# Validation score: 0.474788
# Iteration 42, loss = 0.01703152
# Validation score: 0.473898
# Iteration 43, loss = 0.01651262
# Validation score: 0.472877
# Iteration 44, loss = 0.01610236
# Validation score: 0.470035
# Iteration 45, loss = 0.01567552
# Validation score: 0.468130
# Iteration 46, loss = 0.01532580
# Validation score: 0.467747
# Iteration 47, loss = 0.01494304
# Validation score: 0.467267
# Iteration 48, loss = 0.01448609
# Validation score: 0.467832
# Iteration 49, loss = 0.01407551
# Validation score: 0.469646
# Iteration 50, loss = 0.01367150
# Validation score: 0.470639
# Iteration 51, loss = 0.01330048
# Validation score: 0.471555
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.22110629
# Validation score: -0.464633
# Iteration 2, loss = 0.11388533
# Validation score: -0.067247
# Iteration 3, loss = 0.07311586
# Validation score: -0.069706
# Iteration 4, loss = 0.07845353
# Validation score: -0.143685
# Iteration 5, loss = 0.08741279
# Validation score: -0.079530
# Iteration 6, loss = 0.08162976
# Validation score: 0.067081
# Iteration 7, loss = 0.06697029
# Validation score: 0.187309
# Iteration 8, loss = 0.05408986
# Validation score: 0.230561
# Iteration 9, loss = 0.04852074
# Validation score: 0.213846
# Iteration 10, loss = 0.04832014
# Validation score: 0.192709
# Iteration 11, loss = 0.04891758
# Validation score: 0.202060
# Iteration 12, loss = 0.04738928
# Validation score: 0.242632
# Iteration 13, loss = 0.04378948
# Validation score: 0.294704
# Iteration 14, loss = 0.03970691
# Validation score: 0.341210
# Iteration 15, loss = 0.03750968
# Validation score: 0.370794
# Iteration 16, loss = 0.03654245
# Validation score: 0.381928
# Iteration 17, loss = 0.03603873
# Validation score: 0.384146
# Iteration 18, loss = 0.03478512
# Validation score: 0.377786
# Iteration 19, loss = 0.03271836
# Validation score: 0.359925
# Iteration 20, loss = 0.03104537
# Validation score: 0.333828
# Iteration 21, loss = 0.02990474
# Validation score: 0.312928
# Iteration 22, loss = 0.02917732
# Validation score: 0.303429
# Iteration 23, loss = 0.02820302
# Validation score: 0.305368
# Iteration 24, loss = 0.02700426
# Validation score: 0.310373
# Iteration 25, loss = 0.02588175
# Validation score: 0.316401
# Iteration 26, loss = 0.02500249
# Validation score: 0.321578
# Iteration 27, loss = 0.02437850
# Validation score: 0.321252
# Iteration 28, loss = 0.02369005
# Validation score: 0.317711
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.23435379
# Validation score: -0.048957
# Iteration 2, loss = 0.12604780
# Validation score: 0.480678
# Iteration 3, loss = 0.08161473
# Validation score: 0.582582
# Iteration 4, loss = 0.08412739
# Validation score: 0.533274
# Iteration 5, loss = 0.09410905
# Validation score: 0.527391
# Iteration 6, loss = 0.08920818
# Validation score: 0.568900
# Iteration 7, loss = 0.07375329
# Validation score: 0.576456
# Iteration 8, loss = 0.05840777
# Validation score: 0.508953
# Iteration 9, loss = 0.05125910
# Validation score: 0.387493
# Iteration 10, loss = 0.05245870
# Validation score: 0.277291
# Iteration 11, loss = 0.05420216
# Validation score: 0.237060
# Iteration 12, loss = 0.05319150
# Validation score: 0.263824
# Iteration 13, loss = 0.04886558
# Validation score: 0.332707
# Iteration 14, loss = 0.04384628
# Validation score: 0.405527
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.29514798
# Validation score: -0.646296
# Iteration 2, loss = 0.14544194
# Validation score: -0.053757
# Iteration 3, loss = 0.14788969
# Validation score: 0.063516
# Iteration 4, loss = 0.10333616
# Validation score: 0.397216
# Iteration 5, loss = 0.05400220
# Validation score: -0.230461
# Iteration 6, loss = 0.08134898
# Validation score: 0.029138
# Iteration 7, loss = 0.05431054
# Validation score: 0.514556
# Iteration 8, loss = 0.03499255
# Validation score: 0.580633
# Iteration 9, loss = 0.04509049
# Validation score: 0.530835
# Iteration 10, loss = 0.04576269
# Validation score: 0.529605
# Iteration 11, loss = 0.03300207
# Validation score: 0.432419
# Iteration 12, loss = 0.02897728
# Validation score: 0.266302
# Iteration 13, loss = 0.03193841
# Validation score: 0.227438
# Iteration 14, loss = 0.02969818
# Validation score: 0.324537
# Iteration 15, loss = 0.02407280
# Validation score: 0.439884
# Iteration 16, loss = 0.02283601
# Validation score: 0.498917
# Iteration 17, loss = 0.02398638
# Validation score: 0.509813
# Iteration 18, loss = 0.02171257
# Validation score: 0.480321
# Iteration 19, loss = 0.01840675
# Validation score: 0.418228
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Best parameters: {'ann__learning_rate_init': 0.01}
# Best cross-validation score: -0.11156460911634199

# %%
# XG Boost
from xgboost import XGBRegressor

# Load the dataset
data = pd.read_csv('./train_data_problem1.csv', delimiter=',')

X = data.drop('high_performance', axis=1)
y = data['high_performance']

# Identifying categorical and numerical columns for preprocessing
categorical_columns = X.select_dtypes(include=['object', 'category']).columns
numerical_columns = X.select_dtypes(include=['int', 'float']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns),
        ('scaler', StandardScaler(), numerical_columns)
    ],
    remainder='passthrough'
)

# Creating a modeling pipeline with XGBoost
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('xgb', XGBRegressor(objective='reg:squarederror', random_state=42))
])

# If you want to fine-tune hyperparameters, define a parameter grid
param_grid = {
    'xgb__learning_rate': [0.01, 0.1, 0.2, 0.3, 0.4],
}

# Setting up GridSearchCV for hyperparameter tuning (optional)
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

# Printing the best parameters and cross-validation score
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'xgb__learning_rate': 0.3}
# Best cross-validation score: -2.5123224111063827e-09
