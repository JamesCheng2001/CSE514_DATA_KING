# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge

# Load the dataset
file_path = '/Users/jamescheng/Desktop/WASHU/CSE 514/student+performance/student/student-mat.csv'
data = pd.read_csv(file_path, delimiter=';')

# Drop 'G1' and 'G2' columns
data = data.drop(['G1', 'G2'], axis=1)

# Separate the features and the target variable
X = data.drop('G3', axis=1)
y = data['G3']

# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating the Ridge regression model pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('ridge_regression', Ridge())
])

# Setting up parameter grid for hyperparameter tuning
param_grid = {'ridge_regression__alpha': [0.01, 0.1, 1, 10, 100]}  # alpha is equivalent to λ

# Setting up GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'ridge_regression__alpha': 100}
# Best cross-validation score: -18.694163477538883

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.svm import SVR  # Using SVR for regression

# Load the dataset with the correct delimiter
data = pd.read_csv('/Users/jamescheng/Desktop/WASHU/CSE 514/student+performance/student/student-mat.csv', delimiter=';')

# Drop 'G1' and 'G2' columns
data = data.drop(['G1', 'G2'], axis=1)

# Separate the features and the target variable
X = data.drop('G3', axis=1)
y = data['G3']

# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating the SVM model pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('svm', SVR(C=1.0))
])

# Setting up parameter grid for hyperparameter tuning (C values to test)
param_grid = {'svm__C': [0.1, 1, 10, 100, 1000]}

# Setting up GridSearchCV for 5-fold cross-validation and hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'svm__C': 10}
# Best cross-validation score: -18.551234630666308

# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
# Load the dataset
data = pd.read_csv('/Users/jamescheng/Desktop/WASHU/CSE 514/student+performance/student/student-mat.csv', delimiter=';')

# Drop 'G1' and 'G2' columns
data = data.drop(['G1', 'G2'], axis=1)

# Separate the features and the target variable
X = data.drop('G3', axis=1)
y = data['G3']

# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating the model pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('random_forest', RandomForestRegressor())
])

# Define the parameter grid to test different hyperparameter values
param_grid = {
    'random_forest__n_estimators': [10, 50, 100, 200, 500]
}

# Setting Up GridSearchCV to find the best model configuration using 5-fold cross-validation
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'random_forest__n_estimators': 200}
# Best cross-validation score: -17.40701063291139

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Load the dataset
data = pd.read_csv('/Users/jamescheng/Desktop/WASHU/CSE 514/student+performance/student/student-mat.csv', delimiter=';')

# Drop 'G1' and 'G2' columns
data = data.drop(['G1', 'G2'], axis=1)

# Separate the features and the target variable
X = data.drop('G3', axis=1)
y = data['G3']

# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating a modeling pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('knn', KNeighborsRegressor())
])

# Define the parameter grid to test different values for n_neighbors
param_grid = {'knn__n_neighbors': [1, 3, 5, 7, 9]}

# Setting up GridSearchCV for 5-fold cross-validation and hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'knn__n_neighbors': 9}
# Best cross-validation score: -18.913767776215032

# %%
import pandas as pd
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Load the dataset
data = pd.read_csv('/Users/jamescheng/Desktop/WASHU/CSE 514/student+performance/student/student-mat.csv', delimiter=';')

# Drop 'G1' and 'G2' columns
data = data.drop(['G1', 'G2'], axis=1)

# Separate the features and the target variable
X = data.drop('G3', axis=1)
y = data['G3']

# Identifying categorical columns and numerical columns for preprocessing
categorical_columns = X.select_dtypes(include=['object', 'category']).columns
numerical_columns = X.select_dtypes(include=['int', 'float']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns),
        ('scaler', StandardScaler(), numerical_columns)
    ],
    remainder='passthrough'
)

model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('ann', MLPRegressor(random_state=42, max_iter=1000, verbose=True, early_stopping=True))
])

# Define the parameter grid to test different learning rates
param_grid = {
    'ann__learning_rate_init': [0.1, 0.01, 0.001]
}

# Setting up GridSearchCV for 5-fold cross-validation and hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

# Printing the best cross-validation score
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Iteration 1, loss = 69.61174673
# Validation score: 0.000743
# Iteration 2, loss = 18.51896598
# Validation score: -1.569524
# Iteration 3, loss = 36.18521855
# Validation score: -1.166574
# Iteration 4, loss = 27.84950226
# Validation score: -0.183533
# Iteration 5, loss = 13.71939936
# Validation score: -0.361598
# Iteration 6, loss = 18.62598903
# Validation score: -0.172085
# Iteration 7, loss = 14.83052138
# Validation score: 0.279943
# Iteration 8, loss = 9.82148112
# Validation score: -0.087710
# Iteration 9, loss = 13.69719743
# Validation score: -0.070536
# Iteration 10, loss = 12.66377458
# Validation score: 0.229962
# Iteration 11, loss = 9.57018511
# Validation score: 0.222199
# Iteration 12, loss = 10.80301198
# Validation score: 0.196730
# Iteration 13, loss = 9.79634619
# Validation score: 0.280399
# Iteration 14, loss = 8.33340239
# Validation score: 0.171311
# Iteration 15, loss = 9.34532658
# Validation score: 0.138010
# Iteration 16, loss = 9.13309523
# Validation score: 0.198925
# Iteration 17, loss = 8.08142283
# Validation score: 0.191295
# Iteration 18, loss = 8.16983902
# Validation score: 0.192226
# Iteration 19, loss = 7.75407874
# Validation score: 0.234732
# Iteration 20, loss = 7.16502096
# Validation score: 0.235848
# Iteration 21, loss = 7.36751118
# Validation score: 0.243254
# Iteration 22, loss = 7.20240721
# Validation score: 0.255514
# Iteration 23, loss = 6.89277266
# Validation score: 0.244722
# Iteration 24, loss = 6.82770750
# Validation score: 0.242674
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 67.02630642
# Validation score: -0.039981
# Iteration 2, loss = 17.96668073
# Validation score: -1.834830
# Iteration 3, loss = 34.50470168
# Validation score: -1.091132
# Iteration 4, loss = 23.83988547
# Validation score: -0.088649
# Iteration 5, loss = 12.24823340
# Validation score: -0.808789
# Iteration 6, loss = 19.30569930
# Validation score: 0.027182
# Iteration 7, loss = 10.25239217
# Validation score: 0.048924
# Iteration 8, loss = 10.10090153
# Validation score: -0.472290
# Iteration 9, loss = 13.27931626
# Validation score: -0.155631
# Iteration 10, loss = 9.54332445
# Validation score: 0.126449
# Iteration 11, loss = 8.60745137
# Validation score: 0.051656
# Iteration 12, loss = 10.03057684
# Validation score: 0.215132
# Iteration 13, loss = 7.41870586
# Validation score: 0.176691
# Iteration 14, loss = 7.79870714
# Validation score: 0.072740
# Iteration 15, loss = 8.33054477
# Validation score: 0.166640
# Iteration 16, loss = 6.97432025
# Validation score: 0.221937
# Iteration 17, loss = 6.84538331
# Validation score: 0.214547
# Iteration 18, loss = 6.92770811
# Validation score: 0.261189
# Iteration 19, loss = 6.04910703
# Validation score: 0.250366
# Iteration 20, loss = 6.07636627
# Validation score: 0.233713
# Iteration 21, loss = 6.19449714
# Validation score: 0.265202
# Iteration 22, loss = 5.83441283
# Validation score: 0.261424
# Iteration 23, loss = 5.86416830
# Validation score: 0.254337
# Iteration 24, loss = 5.62227987
# Validation score: 0.250664
# Iteration 25, loss = 5.19617989
# Validation score: 0.221331
# Iteration 26, loss = 5.24099105
# Validation score: 0.204330
# Iteration 27, loss = 5.09129413
# Validation score: 0.217155
# Iteration 28, loss = 4.88145183
# Validation score: 0.208859
# Iteration 29, loss = 4.77385640
# Validation score: 0.206487
# Iteration 30, loss = 4.61048407
# Validation score: 0.199051
# Iteration 31, loss = 4.45055984
# Validation score: 0.196816
# Iteration 32, loss = 4.26803655
# Validation score: 0.196919
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 71.88402439
# Validation score: -0.057982
# Iteration 2, loss = 18.53131087
# Validation score: -1.573915
# Iteration 3, loss = 34.76405047
# Validation score: -0.908644
# Iteration 4, loss = 23.66823417
# Validation score: -0.350440
# Iteration 5, loss = 13.05857660
# Validation score: -1.341632
# Iteration 6, loss = 19.57024916
# Validation score: -0.426512
# Iteration 7, loss = 10.62478950
# Validation score: -0.079519
# Iteration 8, loss = 10.76888951
# Validation score: -0.427157
# Iteration 9, loss = 14.44296981
# Validation score: -0.223530
# Iteration 10, loss = 10.94981219
# Validation score: -0.031075
# Iteration 11, loss = 8.91742087
# Validation score: -0.145348
# Iteration 12, loss = 10.58884392
# Validation score: 0.075601
# Iteration 13, loss = 8.92336017
# Validation score: 0.191240
# Iteration 14, loss = 8.41039402
# Validation score: 0.099057
# Iteration 15, loss = 8.57041913
# Validation score: 0.001031
# Iteration 16, loss = 7.24364375
# Validation score: -0.214480
# Iteration 17, loss = 7.39373157
# Validation score: -0.291748
# Iteration 18, loss = 7.45599822
# Validation score: -0.051960
# Iteration 19, loss = 6.57754833
# Validation score: 0.116891
# Iteration 20, loss = 6.58837924
# Validation score: 0.160730
# Iteration 21, loss = 6.48881808
# Validation score: 0.138974
# Iteration 22, loss = 6.09975900
# Validation score: 0.051573
# Iteration 23, loss = 5.96839985
# Validation score: 0.007549
# Iteration 24, loss = 5.59768148
# Validation score: -0.001121
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 71.43085625
# Validation score: 0.021247
# Iteration 2, loss = 17.88196776
# Validation score: -2.508986
# Iteration 3, loss = 34.71330716
# Validation score: -1.692986
# Iteration 4, loss = 25.60381948
# Validation score: -0.570178
# Iteration 5, loss = 15.20406500
# Validation score: -1.440901
# Iteration 6, loss = 18.78394363
# Validation score: -0.594278
# Iteration 7, loss = 10.40113274
# Validation score: -0.174339
# Iteration 8, loss = 9.15852776
# Validation score: -0.630627
# Iteration 9, loss = 12.89493438
# Validation score: -0.457140
# Iteration 10, loss = 10.98242644
# Validation score: -0.182777
# Iteration 11, loss = 8.82949900
# Validation score: -0.141733
# Iteration 12, loss = 9.01753068
# Validation score: 0.021672
# Iteration 13, loss = 7.94843281
# Validation score: 0.113358
# Iteration 14, loss = 7.61482266
# Validation score: 0.075077
# Iteration 15, loss = 7.78252324
# Validation score: 0.057038
# Iteration 16, loss = 7.07672942
# Validation score: -0.102162
# Iteration 17, loss = 7.06479316
# Validation score: -0.215141
# Iteration 18, loss = 7.15779193
# Validation score: -0.094778
# Iteration 19, loss = 6.49713846
# Validation score: 0.000308
# Iteration 20, loss = 6.51265433
# Validation score: 0.043159
# Iteration 21, loss = 6.24460112
# Validation score: 0.036286
# Iteration 22, loss = 6.11111617
# Validation score: -0.028768
# Iteration 23, loss = 6.32942167
# Validation score: 0.046883
# Iteration 24, loss = 5.89377264
# Validation score: 0.082992
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 63.42989486
# Validation score: -0.332865
# Iteration 2, loss = 18.10624836
# Validation score: -1.303978
# Iteration 3, loss = 23.94814177
# Validation score: 0.263272
# Iteration 4, loss = 9.72642213
# Validation score: 0.283392
# Iteration 5, loss = 15.61405632
# Validation score: 0.542749
# Iteration 6, loss = 8.37655028
# Validation score: -0.020734
# Iteration 7, loss = 11.56291883
# Validation score: -0.116271
# Iteration 8, loss = 10.47300110
# Validation score: 0.294222
# Iteration 9, loss = 7.79056415
# Validation score: 0.195575
# Iteration 10, loss = 10.04671779
# Validation score: 0.396929
# Iteration 11, loss = 7.25152905
# Validation score: 0.324893
# Iteration 12, loss = 7.41472752
# Validation score: 0.263246
# Iteration 13, loss = 7.64278472
# Validation score: 0.440407
# Iteration 14, loss = 6.53907171
# Validation score: 0.432853
# Iteration 15, loss = 6.68332963
# Validation score: 0.432648
# Iteration 16, loss = 6.21374351
# Validation score: 0.437167
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 55.22511299
# Validation score: -1.371791
# Iteration 2, loss = 29.92996074
# Validation score: -0.173434
# Iteration 3, loss = 14.24097271
# Validation score: 0.090924
# Iteration 4, loss = 11.03359794
# Validation score: -0.408238
# Iteration 5, loss = 16.16276439
# Validation score: -0.395678
# Iteration 6, loss = 15.18625770
# Validation score: -0.044419
# Iteration 7, loss = 11.04686780
# Validation score: 0.176819
# Iteration 8, loss = 9.25170278
# Validation score: 0.182055
# Iteration 9, loss = 9.60013758
# Validation score: 0.126016
# Iteration 10, loss = 10.47319333
# Validation score: 0.109430
# Iteration 11, loss = 10.50920270
# Validation score: 0.148593
# Iteration 12, loss = 9.78053804
# Validation score: 0.202673
# Iteration 13, loss = 8.89483271
# Validation score: 0.224010
# Iteration 14, loss = 8.50842239
# Validation score: 0.207450
# Iteration 15, loss = 8.60329530
# Validation score: 0.190097
# Iteration 16, loss = 8.71644723
# Validation score: 0.198949
# Iteration 17, loss = 8.55184832
# Validation score: 0.222905
# Iteration 18, loss = 8.25414619
# Validation score: 0.240686
# Iteration 19, loss = 8.05222205
# Validation score: 0.244794
# Iteration 20, loss = 8.02798499
# Validation score: 0.242722
# Iteration 21, loss = 8.02154150
# Validation score: 0.243058
# Iteration 22, loss = 7.95311486
# Validation score: 0.246841
# Iteration 23, loss = 7.83179029
# Validation score: 0.246976
# Iteration 24, loss = 7.70472336
# Validation score: 0.242423
# Iteration 25, loss = 7.71145579
# Validation score: 0.236490
# Iteration 26, loss = 7.63698379
# Validation score: 0.235464
# Iteration 27, loss = 7.54435508
# Validation score: 0.234894
# Iteration 28, loss = 7.47608821
# Validation score: 0.233868
# Iteration 29, loss = 7.40620602
# Validation score: 0.232027
# Iteration 30, loss = 7.39115119
# Validation score: 0.229546
# Iteration 31, loss = 7.32758417
# Validation score: 0.228953
# Iteration 32, loss = 7.25306235
# Validation score: 0.226185
# Iteration 33, loss = 7.22080011
# Validation score: 0.222154
# Iteration 34, loss = 7.17753114
# Validation score: 0.221977
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 57.15920911
# Validation score: -1.996915
# Iteration 2, loss = 30.48317749
# Validation score: -0.453392
# Iteration 3, loss = 13.49510481
# Validation score: 0.140630
# Iteration 4, loss = 8.65697084
# Validation score: -0.266727
# Iteration 5, loss = 14.20788774
# Validation score: -0.343902
# Iteration 6, loss = 14.41923916
# Validation score: 0.005152
# Iteration 7, loss = 9.96953897
# Validation score: 0.236323
# Iteration 8, loss = 7.55104766
# Validation score: 0.216294
# Iteration 9, loss = 7.56933886
# Validation score: 0.112957
# Iteration 10, loss = 8.71215870
# Validation score: 0.061433
# Iteration 11, loss = 9.07179799
# Validation score: 0.102824
# Iteration 12, loss = 8.48925592
# Validation score: 0.195444
# Iteration 13, loss = 7.46911880
# Validation score: 0.270572
# Iteration 14, loss = 6.85694750
# Validation score: 0.298200
# Iteration 15, loss = 6.79550108
# Validation score: 0.293158
# Iteration 16, loss = 6.99562348
# Validation score: 0.292782
# Iteration 17, loss = 7.00088497
# Validation score: 0.304366
# Iteration 18, loss = 6.72740949
# Validation score: 0.312458
# Iteration 19, loss = 6.47397283
# Validation score: 0.305456
# Iteration 20, loss = 6.37380256
# Validation score: 0.290068
# Iteration 21, loss = 6.39739185
# Validation score: 0.282247
# Iteration 22, loss = 6.36701447
# Validation score: 0.289216
# Iteration 23, loss = 6.27696973
# Validation score: 0.301637
# Iteration 24, loss = 6.13704403
# Validation score: 0.311065
# Iteration 25, loss = 6.13548377
# Validation score: 0.313909
# Iteration 26, loss = 6.07444647
# Validation score: 0.310319
# Iteration 27, loss = 6.01719936
# Validation score: 0.307558
# Iteration 28, loss = 5.95481070
# Validation score: 0.302116
# Iteration 29, loss = 5.88030252
# Validation score: 0.294773
# Iteration 30, loss = 5.87422187
# Validation score: 0.288118
# Iteration 31, loss = 5.83153164
# Validation score: 0.289312
# Iteration 32, loss = 5.77173569
# Validation score: 0.295381
# Iteration 33, loss = 5.72511549
# Validation score: 0.302278
# Iteration 34, loss = 5.67543819
# Validation score: 0.305243
# Iteration 35, loss = 5.65769628
# Validation score: 0.306656
# Iteration 36, loss = 5.61076996
# Validation score: 0.305750
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 58.99619715
# Validation score: -1.692311
# Iteration 2, loss = 32.16624265
# Validation score: -0.314040
# Iteration 3, loss = 15.44508831
# Validation score: 0.013747
# Iteration 4, loss = 10.34000676
# Validation score: -0.617229
# Iteration 5, loss = 15.60090594
# Validation score: -0.718341
# Iteration 6, loss = 15.56128827
# Validation score: -0.277082
# Iteration 7, loss = 11.19723276
# Validation score: 0.062182
# Iteration 8, loss = 8.79125931
# Validation score: 0.134908
# Iteration 9, loss = 8.92045495
# Validation score: 0.086583
# Iteration 10, loss = 10.10273395
# Validation score: 0.053059
# Iteration 11, loss = 10.37241149
# Validation score: 0.077763
# Iteration 12, loss = 9.66746516
# Validation score: 0.123524
# Iteration 13, loss = 8.57576053
# Validation score: 0.126430
# Iteration 14, loss = 8.05252318
# Validation score: 0.073970
# Iteration 15, loss = 8.07526403
# Validation score: 0.019221
# Iteration 16, loss = 8.27170294
# Validation score: 0.012916
# Iteration 17, loss = 8.23593994
# Validation score: 0.049511
# Iteration 18, loss = 7.89347270
# Validation score: 0.095683
# Iteration 19, loss = 7.61309537
# Validation score: 0.127981
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 57.00933893
# Validation score: -2.604145
# Iteration 2, loss = 30.53720890
# Validation score: -0.587122
# Iteration 3, loss = 14.23417888
# Validation score: -0.008841
# Iteration 4, loss = 9.70883952
# Validation score: -0.780775
# Iteration 5, loss = 15.09907212
# Validation score: -0.922572
# Iteration 6, loss = 14.55911685
# Validation score: -0.384199
# Iteration 7, loss = 10.11641712
# Validation score: -0.005381
# Iteration 8, loss = 7.79376276
# Validation score: 0.032341
# Iteration 9, loss = 8.17708296
# Validation score: -0.064508
# Iteration 10, loss = 9.52340542
# Validation score: -0.122803
# Iteration 11, loss = 9.86980729
# Validation score: -0.087340
# Iteration 12, loss = 9.09734379
# Validation score: -0.012799
# Iteration 13, loss = 7.87580040
# Validation score: 0.002311
# Iteration 14, loss = 7.29264133
# Validation score: -0.069976
# Iteration 15, loss = 7.30650801
# Validation score: -0.153672
# Iteration 16, loss = 7.67100838
# Validation score: -0.165830
# Iteration 17, loss = 7.72753096
# Validation score: -0.094645
# Iteration 18, loss = 7.32390488
# Validation score: -0.001355
# Iteration 19, loss = 6.94360137
# Validation score: 0.064955
# Iteration 20, loss = 6.76046378
# Validation score: 0.093376
# Iteration 21, loss = 6.83476118
# Validation score: 0.105090
# Iteration 22, loss = 6.82888178
# Validation score: 0.124334
# Iteration 23, loss = 6.71293535
# Validation score: 0.141853
# Iteration 24, loss = 6.54833749
# Validation score: 0.147646
# Iteration 25, loss = 6.46127113
# Validation score: 0.142522
# Iteration 26, loss = 6.45481662
# Validation score: 0.135113
# Iteration 27, loss = 6.44683740
# Validation score: 0.141002
# Iteration 28, loss = 6.36243105
# Validation score: 0.152390
# Iteration 29, loss = 6.26955268
# Validation score: 0.156502
# Iteration 30, loss = 6.23079391
# Validation score: 0.154592
# Iteration 31, loss = 6.21243031
# Validation score: 0.152821
# Iteration 32, loss = 6.16772141
# Validation score: 0.152954
# Iteration 33, loss = 6.10356597
# Validation score: 0.157091
# Iteration 34, loss = 6.05270982
# Validation score: 0.160881
# Iteration 35, loss = 6.02416931
# Validation score: 0.164019
# Iteration 36, loss = 6.00972140
# Validation score: 0.172543
# Iteration 37, loss = 5.97140229
# Validation score: 0.179731
# Iteration 38, loss = 5.92364308
# Validation score: 0.185647
# Iteration 39, loss = 5.88447784
# Validation score: 0.189583
# Iteration 40, loss = 5.83693907
# Validation score: 0.191596
# Iteration 41, loss = 5.80147044
# Validation score: 0.194884
# Iteration 42, loss = 5.76350706
# Validation score: 0.193205
# Iteration 43, loss = 5.72419228
# Validation score: 0.186715
# Iteration 44, loss = 5.69522835
# Validation score: 0.185390
# Iteration 45, loss = 5.65772092
# Validation score: 0.184643
# Iteration 46, loss = 5.61050424
# Validation score: 0.182566
# Iteration 47, loss = 5.56019675
# Validation score: 0.181815
# Iteration 48, loss = 5.52415420
# Validation score: 0.179935
# Iteration 49, loss = 5.48552652
# Validation score: 0.175894
# Iteration 50, loss = 5.43464856
# Validation score: 0.173776
# Iteration 51, loss = 5.39919603
# Validation score: 0.170029
# Iteration 52, loss = 5.36243645
# Validation score: 0.168797
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 63.65424994
# Validation score: -2.599585
# Iteration 2, loss = 37.42889568
# Validation score: -0.949692
# Iteration 3, loss = 19.01678177
# Validation score: 0.133117
# Iteration 4, loss = 9.21414481
# Validation score: 0.296745
# Iteration 5, loss = 12.57762934
# Validation score: 0.088053
# Iteration 6, loss = 15.81021085
# Validation score: 0.203376
# Iteration 7, loss = 12.55766710
# Validation score: 0.361495
# Iteration 8, loss = 8.92343216
# Validation score: 0.360436
# Iteration 9, loss = 7.59717826
# Validation score: 0.264480
# Iteration 10, loss = 8.34792868
# Validation score: 0.191590
# Iteration 11, loss = 9.04871740
# Validation score: 0.202743
# Iteration 12, loss = 8.91987831
# Validation score: 0.281710
# Iteration 13, loss = 8.12990766
# Validation score: 0.378122
# Iteration 14, loss = 7.44631873
# Validation score: 0.439632
# Iteration 15, loss = 7.00573470
# Validation score: 0.455218
# Iteration 16, loss = 7.14524492
# Validation score: 0.450865
# Iteration 17, loss = 7.29979181
# Validation score: 0.451312
# Iteration 18, loss = 7.22348931
# Validation score: 0.453909
# Iteration 19, loss = 6.92396553
# Validation score: 0.449159
# Iteration 20, loss = 6.67799863
# Validation score: 0.430897
# Iteration 21, loss = 6.63329819
# Validation score: 0.406112
# Iteration 22, loss = 6.66628898
# Validation score: 0.392533
# Iteration 23, loss = 6.65282760
# Validation score: 0.393084
# Iteration 24, loss = 6.53666483
# Validation score: 0.402128
# Iteration 25, loss = 6.42757311
# Validation score: 0.410609
# Iteration 26, loss = 6.39398060
# Validation score: 0.414605
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 58.58930421
# Validation score: -2.989114
# Iteration 2, loss = 55.61193410
# Validation score: -2.789818
# Iteration 3, loss = 52.81808725
# Validation score: -2.594939
# Iteration 4, loss = 50.05345742
# Validation score: -2.407103
# Iteration 5, loss = 47.35838713
# Validation score: -2.224908
# Iteration 6, loss = 44.80822840
# Validation score: -2.047934
# Iteration 7, loss = 42.29018667
# Validation score: -1.875847
# Iteration 8, loss = 39.82710463
# Validation score: -1.707832
# Iteration 9, loss = 37.47833601
# Validation score: -1.544702
# Iteration 10, loss = 35.15856231
# Validation score: -1.387413
# Iteration 11, loss = 32.89684641
# Validation score: -1.235034
# Iteration 12, loss = 30.78042508
# Validation score: -1.087488
# Iteration 13, loss = 28.64979474
# Validation score: -0.946793
# Iteration 14, loss = 26.66224240
# Validation score: -0.813191
# Iteration 15, loss = 24.69964233
# Validation score: -0.687218
# Iteration 16, loss = 22.84363399
# Validation score: -0.569588
# Iteration 17, loss = 21.06031672
# Validation score: -0.459485
# Iteration 18, loss = 19.43064921
# Validation score: -0.357032
# Iteration 19, loss = 17.89223762
# Validation score: -0.263580
# Iteration 20, loss = 16.47735525
# Validation score: -0.179536
# Iteration 21, loss = 15.18913343
# Validation score: -0.105435
# Iteration 22, loss = 14.04607028
# Validation score: -0.041213
# Iteration 23, loss = 13.05979366
# Validation score: 0.012742
# Iteration 24, loss = 12.18013939
# Validation score: 0.056346
# Iteration 25, loss = 11.54038206
# Validation score: 0.089946
# Iteration 26, loss = 10.89844971
# Validation score: 0.114102
# Iteration 27, loss = 10.47699760
# Validation score: 0.130979
# Iteration 28, loss = 10.16574111
# Validation score: 0.141316
# Iteration 29, loss = 9.93043285
# Validation score: 0.146440
# Iteration 30, loss = 9.74536384
# Validation score: 0.147832
# Iteration 31, loss = 9.66182035
# Validation score: 0.147033
# Iteration 32, loss = 9.60760414
# Validation score: 0.144924
# Iteration 33, loss = 9.60552616
# Validation score: 0.142456
# Iteration 34, loss = 9.58102146
# Validation score: 0.140647
# Iteration 35, loss = 9.58411433
# Validation score: 0.139605
# Iteration 36, loss = 9.56308918
# Validation score: 0.139665
# Iteration 37, loss = 9.54450157
# Validation score: 0.140919
# Iteration 38, loss = 9.51525180
# Validation score: 0.143305
# Iteration 39, loss = 9.47876001
# Validation score: 0.146746
# Iteration 40, loss = 9.42947597
# Validation score: 0.151534
# Iteration 41, loss = 9.37406871
# Validation score: 0.156830
# Iteration 42, loss = 9.32055937
# Validation score: 0.161991
# Iteration 43, loss = 9.26751151
# Validation score: 0.166880
# Iteration 44, loss = 9.21276554
# Validation score: 0.171389
# Iteration 45, loss = 9.16597593
# Validation score: 0.175591
# Iteration 46, loss = 9.12186998
# Validation score: 0.179521
# Iteration 47, loss = 9.08509391
# Validation score: 0.183007
# Iteration 48, loss = 9.05939007
# Validation score: 0.186158
# Iteration 49, loss = 9.03301712
# Validation score: 0.188782
# Iteration 50, loss = 8.99455337
# Validation score: 0.191081
# Iteration 51, loss = 8.96942649
# Validation score: 0.193499
# Iteration 52, loss = 8.94788710
# Validation score: 0.195754
# Iteration 53, loss = 8.91964316
# Validation score: 0.197680
# Iteration 54, loss = 8.88886310
# Validation score: 0.199352
# Iteration 55, loss = 8.86486631
# Validation score: 0.200948
# Iteration 56, loss = 8.83603431
# Validation score: 0.202432
# Iteration 57, loss = 8.80801970
# Validation score: 0.203635
# Iteration 58, loss = 8.78054566
# Validation score: 0.204799
# Iteration 59, loss = 8.75552126
# Validation score: 0.205792
# Iteration 60, loss = 8.72879281
# Validation score: 0.206519
# Iteration 61, loss = 8.70487119
# Validation score: 0.207067
# Iteration 62, loss = 8.68217039
# Validation score: 0.207486
# Iteration 63, loss = 8.65928422
# Validation score: 0.207819
# Iteration 64, loss = 8.63486066
# Validation score: 0.208124
# Iteration 65, loss = 8.61455784
# Validation score: 0.208393
# Iteration 66, loss = 8.59364543
# Validation score: 0.208909
# Iteration 67, loss = 8.57186937
# Validation score: 0.209681
# Iteration 68, loss = 8.54797758
# Validation score: 0.210460
# Iteration 69, loss = 8.52629200
# Validation score: 0.211149
# Iteration 70, loss = 8.50218725
# Validation score: 0.211545
# Iteration 71, loss = 8.48237073
# Validation score: 0.211943
# Iteration 72, loss = 8.46108055
# Validation score: 0.212392
# Iteration 73, loss = 8.44058806
# Validation score: 0.212817
# Iteration 74, loss = 8.42017390
# Validation score: 0.213103
# Iteration 75, loss = 8.40143735
# Validation score: 0.213837
# Iteration 76, loss = 8.38077571
# Validation score: 0.214632
# Iteration 77, loss = 8.36015536
# Validation score: 0.215108
# Iteration 78, loss = 8.34063162
# Validation score: 0.215595
# Iteration 79, loss = 8.32208702
# Validation score: 0.216047
# Iteration 80, loss = 8.30204540
# Validation score: 0.216706
# Iteration 81, loss = 8.28185198
# Validation score: 0.217450
# Iteration 82, loss = 8.26135434
# Validation score: 0.218453
# Iteration 83, loss = 8.24182305
# Validation score: 0.219411
# Iteration 84, loss = 8.22255074
# Validation score: 0.220162
# Iteration 85, loss = 8.20177497
# Validation score: 0.220549
# Iteration 86, loss = 8.18205609
# Validation score: 0.220873
# Iteration 87, loss = 8.16395124
# Validation score: 0.221471
# Iteration 88, loss = 8.14335313
# Validation score: 0.222174
# Iteration 89, loss = 8.12324997
# Validation score: 0.223259
# Iteration 90, loss = 8.10801030
# Validation score: 0.224239
# Iteration 91, loss = 8.08710188
# Validation score: 0.225131
# Iteration 92, loss = 8.06952371
# Validation score: 0.226066
# Iteration 93, loss = 8.05203030
# Validation score: 0.226895
# Iteration 94, loss = 8.03342642
# Validation score: 0.227762
# Iteration 95, loss = 8.01616190
# Validation score: 0.228267
# Iteration 96, loss = 7.99924779
# Validation score: 0.228659
# Iteration 97, loss = 7.98112053
# Validation score: 0.228921
# Iteration 98, loss = 7.96667686
# Validation score: 0.229220
# Iteration 99, loss = 7.94719550
# Validation score: 0.229917
# Iteration 100, loss = 7.93044239
# Validation score: 0.230334
# Iteration 101, loss = 7.91348311
# Validation score: 0.230667
# Iteration 102, loss = 7.89751713
# Validation score: 0.231124
# Iteration 103, loss = 7.87994191
# Validation score: 0.231341
# Iteration 104, loss = 7.86323582
# Validation score: 0.231585
# Iteration 105, loss = 7.84731847
# Validation score: 0.231688
# Iteration 106, loss = 7.83029972
# Validation score: 0.231800
# Iteration 107, loss = 7.81457385
# Validation score: 0.231812
# Iteration 108, loss = 7.79761496
# Validation score: 0.231564
# Iteration 109, loss = 7.78257511
# Validation score: 0.231152
# Iteration 110, loss = 7.76501804
# Validation score: 0.230780
# Iteration 111, loss = 7.75100666
# Validation score: 0.230351
# Iteration 112, loss = 7.73431270
# Validation score: 0.230134
# Iteration 113, loss = 7.71713128
# Validation score: 0.230213
# Iteration 114, loss = 7.69961648
# Validation score: 0.230288
# Iteration 115, loss = 7.68362296
# Validation score: 0.230274
# Iteration 116, loss = 7.67046416
# Validation score: 0.230008
# Iteration 117, loss = 7.65080115
# Validation score: 0.229518
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 60.85576818
# Validation score: -3.933708
# Iteration 2, loss = 57.73596422
# Validation score: -3.698994
# Iteration 3, loss = 54.80968564
# Validation score: -3.470399
# Iteration 4, loss = 51.88905769
# Validation score: -3.246983
# Iteration 5, loss = 49.08176432
# Validation score: -3.030504
# Iteration 6, loss = 46.36168306
# Validation score: -2.819659
# Iteration 7, loss = 43.72203248
# Validation score: -2.612770
# Iteration 8, loss = 41.10683275
# Validation score: -2.409402
# Iteration 9, loss = 38.62710543
# Validation score: -2.209710
# Iteration 10, loss = 36.15856467
# Validation score: -2.016034
# Iteration 11, loss = 33.75808692
# Validation score: -1.827206
# Iteration 12, loss = 31.49206774
# Validation score: -1.644415
# Iteration 13, loss = 29.22552554
# Validation score: -1.468703
# Iteration 14, loss = 27.08832978
# Validation score: -1.299703
# Iteration 15, loss = 24.98218099
# Validation score: -1.137289
# Iteration 16, loss = 22.97663807
# Validation score: -0.982677
# Iteration 17, loss = 21.02070350
# Validation score: -0.835726
# Iteration 18, loss = 19.25224678
# Validation score: -0.695810
# Iteration 19, loss = 17.53235841
# Validation score: -0.564835
# Iteration 20, loss = 15.95177663
# Validation score: -0.443690
# Iteration 21, loss = 14.49868394
# Validation score: -0.333024
# Iteration 22, loss = 13.20873261
# Validation score: -0.233215
# Iteration 23, loss = 12.07111711
# Validation score: -0.145631
# Iteration 24, loss = 11.01710613
# Validation score: -0.070500
# Iteration 25, loss = 10.22043490
# Validation score: -0.007177
# Iteration 26, loss = 9.46620383
# Validation score: 0.043943
# Iteration 27, loss = 8.91715596
# Validation score: 0.084763
# Iteration 28, loss = 8.49322413
# Validation score: 0.116412
# Iteration 29, loss = 8.17428645
# Validation score: 0.139866
# Iteration 30, loss = 7.91998744
# Validation score: 0.156658
# Iteration 31, loss = 7.77383047
# Validation score: 0.168308
# Iteration 32, loss = 7.68994418
# Validation score: 0.176162
# Iteration 33, loss = 7.65956489
# Validation score: 0.181441
# Iteration 34, loss = 7.61827927
# Validation score: 0.185005
# Iteration 35, loss = 7.62620229
# Validation score: 0.187759
# Iteration 36, loss = 7.61337054
# Validation score: 0.190303
# Iteration 37, loss = 7.60631025
# Validation score: 0.192969
# Iteration 38, loss = 7.58816249
# Validation score: 0.195804
# Iteration 39, loss = 7.56551248
# Validation score: 0.198928
# Iteration 40, loss = 7.53182305
# Validation score: 0.202389
# Iteration 41, loss = 7.49119889
# Validation score: 0.206038
# Iteration 42, loss = 7.44867504
# Validation score: 0.209516
# Iteration 43, loss = 7.40349378
# Validation score: 0.212644
# Iteration 44, loss = 7.35666563
# Validation score: 0.215379
# Iteration 45, loss = 7.31408085
# Validation score: 0.217965
# Iteration 46, loss = 7.27555750
# Validation score: 0.220234
# Iteration 47, loss = 7.23941397
# Validation score: 0.221979
# Iteration 48, loss = 7.21354765
# Validation score: 0.223503
# Iteration 49, loss = 7.18717775
# Validation score: 0.224941
# Iteration 50, loss = 7.15509368
# Validation score: 0.226106
# Iteration 51, loss = 7.13337832
# Validation score: 0.227327
# Iteration 52, loss = 7.11218055
# Validation score: 0.228605
# Iteration 53, loss = 7.08986875
# Validation score: 0.229771
# Iteration 54, loss = 7.06709872
# Validation score: 0.230966
# Iteration 55, loss = 7.04896576
# Validation score: 0.232111
# Iteration 56, loss = 7.02706097
# Validation score: 0.233462
# Iteration 57, loss = 7.00804469
# Validation score: 0.234687
# Iteration 58, loss = 6.98741579
# Validation score: 0.236037
# Iteration 59, loss = 6.96674220
# Validation score: 0.237491
# Iteration 60, loss = 6.94720040
# Validation score: 0.238846
# Iteration 61, loss = 6.92936119
# Validation score: 0.240203
# Iteration 62, loss = 6.91098698
# Validation score: 0.241586
# Iteration 63, loss = 6.89148174
# Validation score: 0.242898
# Iteration 64, loss = 6.87362497
# Validation score: 0.244099
# Iteration 65, loss = 6.85683738
# Validation score: 0.245283
# Iteration 66, loss = 6.83869676
# Validation score: 0.246089
# Iteration 67, loss = 6.82154352
# Validation score: 0.246888
# Iteration 68, loss = 6.80257461
# Validation score: 0.247332
# Iteration 69, loss = 6.78574150
# Validation score: 0.247695
# Iteration 70, loss = 6.76641558
# Validation score: 0.248255
# Iteration 71, loss = 6.75010331
# Validation score: 0.248841
# Iteration 72, loss = 6.73404554
# Validation score: 0.249354
# Iteration 73, loss = 6.71612604
# Validation score: 0.250007
# Iteration 74, loss = 6.70171126
# Validation score: 0.250638
# Iteration 75, loss = 6.68545204
# Validation score: 0.251479
# Iteration 76, loss = 6.66997522
# Validation score: 0.252277
# Iteration 77, loss = 6.65270527
# Validation score: 0.252830
# Iteration 78, loss = 6.63775628
# Validation score: 0.253219
# Iteration 79, loss = 6.62255092
# Validation score: 0.253574
# Iteration 80, loss = 6.60672715
# Validation score: 0.254605
# Iteration 81, loss = 6.58918771
# Validation score: 0.255715
# Iteration 82, loss = 6.57337401
# Validation score: 0.256817
# Iteration 83, loss = 6.55623718
# Validation score: 0.258350
# Iteration 84, loss = 6.54097343
# Validation score: 0.259847
# Iteration 85, loss = 6.52440628
# Validation score: 0.261317
# Iteration 86, loss = 6.50908669
# Validation score: 0.262841
# Iteration 87, loss = 6.49640080
# Validation score: 0.264153
# Iteration 88, loss = 6.48059529
# Validation score: 0.265192
# Iteration 89, loss = 6.46492622
# Validation score: 0.266105
# Iteration 90, loss = 6.45165010
# Validation score: 0.267065
# Iteration 91, loss = 6.43685482
# Validation score: 0.268036
# Iteration 92, loss = 6.42262964
# Validation score: 0.269205
# Iteration 93, loss = 6.41116195
# Validation score: 0.270221
# Iteration 94, loss = 6.39622366
# Validation score: 0.270864
# Iteration 95, loss = 6.38226050
# Validation score: 0.271481
# Iteration 96, loss = 6.36894826
# Validation score: 0.272172
# Iteration 97, loss = 6.35484034
# Validation score: 0.272804
# Iteration 98, loss = 6.34067726
# Validation score: 0.273553
# Iteration 99, loss = 6.32659417
# Validation score: 0.273926
# Iteration 100, loss = 6.31210881
# Validation score: 0.273840
# Iteration 101, loss = 6.29959864
# Validation score: 0.273698
# Iteration 102, loss = 6.28660408
# Validation score: 0.273839
# Iteration 103, loss = 6.27103087
# Validation score: 0.274426
# Iteration 104, loss = 6.25739666
# Validation score: 0.275208
# Iteration 105, loss = 6.24381901
# Validation score: 0.275969
# Iteration 106, loss = 6.22896029
# Validation score: 0.276756
# Iteration 107, loss = 6.21584924
# Validation score: 0.277113
# Iteration 108, loss = 6.20034095
# Validation score: 0.277451
# Iteration 109, loss = 6.18751438
# Validation score: 0.278000
# Iteration 110, loss = 6.17160244
# Validation score: 0.278684
# Iteration 111, loss = 6.15929610
# Validation score: 0.279118
# Iteration 112, loss = 6.14465276
# Validation score: 0.279466
# Iteration 113, loss = 6.13015195
# Validation score: 0.279678
# Iteration 114, loss = 6.11433476
# Validation score: 0.279672
# Iteration 115, loss = 6.10077205
# Validation score: 0.279651
# Iteration 116, loss = 6.08870639
# Validation score: 0.279518
# Iteration 117, loss = 6.07204513
# Validation score: 0.279857
# Iteration 118, loss = 6.05837755
# Validation score: 0.280090
# Iteration 119, loss = 6.04310322
# Validation score: 0.280682
# Iteration 120, loss = 6.02991773
# Validation score: 0.281270
# Iteration 121, loss = 6.01524521
# Validation score: 0.281357
# Iteration 122, loss = 6.00091716
# Validation score: 0.281293
# Iteration 123, loss = 5.98662977
# Validation score: 0.280806
# Iteration 124, loss = 5.97378968
# Validation score: 0.280193
# Iteration 125, loss = 5.96208408
# Validation score: 0.280145
# Iteration 126, loss = 5.94537400
# Validation score: 0.280821
# Iteration 127, loss = 5.93150332
# Validation score: 0.281645
# Iteration 128, loss = 5.91883971
# Validation score: 0.282271
# Iteration 129, loss = 5.90376491
# Validation score: 0.282396
# Iteration 130, loss = 5.88923100
# Validation score: 0.282410
# Iteration 131, loss = 5.87535234
# Validation score: 0.282403
# Iteration 132, loss = 5.86108132
# Validation score: 0.282650
# Iteration 133, loss = 5.84761795
# Validation score: 0.283031
# Iteration 134, loss = 5.83461299
# Validation score: 0.283642
# Iteration 135, loss = 5.82109174
# Validation score: 0.284100
# Iteration 136, loss = 5.80534481
# Validation score: 0.284270
# Iteration 137, loss = 5.79107372
# Validation score: 0.284265
# Iteration 138, loss = 5.77750251
# Validation score: 0.283915
# Iteration 139, loss = 5.76190925
# Validation score: 0.283549
# Iteration 140, loss = 5.74645363
# Validation score: 0.283090
# Iteration 141, loss = 5.73187237
# Validation score: 0.282588
# Iteration 142, loss = 5.71670257
# Validation score: 0.281959
# Iteration 143, loss = 5.70123234
# Validation score: 0.281415
# Iteration 144, loss = 5.68608405
# Validation score: 0.280972
# Iteration 145, loss = 5.67307273
# Validation score: 0.280589
# Iteration 146, loss = 5.65652393
# Validation score: 0.280567
# Iteration 147, loss = 5.64035765
# Validation score: 0.280387
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 62.51830113
# Validation score: -3.544378
# Iteration 2, loss = 59.39333369
# Validation score: -3.314671
# Iteration 3, loss = 56.51357598
# Validation score: -3.090374
# Iteration 4, loss = 53.60760086
# Validation score: -2.874779
# Iteration 5, loss = 50.82812082
# Validation score: -2.665846
# Iteration 6, loss = 48.12068768
# Validation score: -2.462605
# Iteration 7, loss = 45.47671733
# Validation score: -2.264033
# Iteration 8, loss = 42.87976297
# Validation score: -2.071399
# Iteration 9, loss = 40.40886812
# Validation score: -1.884503
# Iteration 10, loss = 37.89659091
# Validation score: -1.703610
# Iteration 11, loss = 35.50505744
# Validation score: -1.528904
# Iteration 12, loss = 33.23444242
# Validation score: -1.359871
# Iteration 13, loss = 30.91429504
# Validation score: -1.196996
# Iteration 14, loss = 28.77226872
# Validation score: -1.041122
# Iteration 15, loss = 26.65865429
# Validation score: -0.894564
# Iteration 16, loss = 24.59329079
# Validation score: -0.756529
# Iteration 17, loss = 22.64345474
# Validation score: -0.626675
# Iteration 18, loss = 20.85264087
# Validation score: -0.505707
# Iteration 19, loss = 19.12479794
# Validation score: -0.395304
# Iteration 20, loss = 17.54534187
# Validation score: -0.296336
# Iteration 21, loss = 16.08915579
# Validation score: -0.208896
# Iteration 22, loss = 14.80535751
# Validation score: -0.133244
# Iteration 23, loss = 13.65451225
# Validation score: -0.069947
# Iteration 24, loss = 12.62871608
# Validation score: -0.018989
# Iteration 25, loss = 11.82499399
# Validation score: 0.020714
# Iteration 26, loss = 11.09086764
# Validation score: 0.049083
# Iteration 27, loss = 10.56261092
# Validation score: 0.067564
# Iteration 28, loss = 10.11150306
# Validation score: 0.077526
# Iteration 29, loss = 9.80161962
# Validation score: 0.080783
# Iteration 30, loss = 9.55226821
# Validation score: 0.078811
# Iteration 31, loss = 9.40069544
# Validation score: 0.073551
# Iteration 32, loss = 9.32391496
# Validation score: 0.066316
# Iteration 33, loss = 9.28631661
# Validation score: 0.059097
# Iteration 34, loss = 9.23350300
# Validation score: 0.052584
# Iteration 35, loss = 9.23630487
# Validation score: 0.047307
# Iteration 36, loss = 9.21572165
# Validation score: 0.044343
# Iteration 37, loss = 9.19388863
# Validation score: 0.043487
# Iteration 38, loss = 9.16161271
# Validation score: 0.044765
# Iteration 39, loss = 9.11998763
# Validation score: 0.047808
# Iteration 40, loss = 9.06982103
# Validation score: 0.052022
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 60.38463784
# Validation score: -5.221484
# Iteration 2, loss = 57.30009517
# Validation score: -4.900011
# Iteration 3, loss = 54.46089901
# Validation score: -4.585743
# Iteration 4, loss = 51.60859933
# Validation score: -4.282806
# Iteration 5, loss = 48.90081407
# Validation score: -3.989543
# Iteration 6, loss = 46.21290679
# Validation score: -3.703879
# Iteration 7, loss = 43.59884500
# Validation score: -3.423610
# Iteration 8, loss = 41.09514526
# Validation score: -3.149101
# Iteration 9, loss = 38.65681710
# Validation score: -2.882328
# Iteration 10, loss = 36.18082441
# Validation score: -2.624362
# Iteration 11, loss = 33.82180492
# Validation score: -2.372774
# Iteration 12, loss = 31.59632349
# Validation score: -2.127699
# Iteration 13, loss = 29.32340537
# Validation score: -1.891201
# Iteration 14, loss = 27.21972386
# Validation score: -1.664288
# Iteration 15, loss = 25.12799418
# Validation score: -1.448076
# Iteration 16, loss = 23.11795583
# Validation score: -1.242979
# Iteration 17, loss = 21.21392815
# Validation score: -1.049911
# Iteration 18, loss = 19.47242339
# Validation score: -0.869624
# Iteration 19, loss = 17.78606522
# Validation score: -0.705095
# Iteration 20, loss = 16.29042666
# Validation score: -0.556491
# Iteration 21, loss = 14.84764995
# Validation score: -0.424910
# Iteration 22, loss = 13.64320636
# Validation score: -0.309775
# Iteration 23, loss = 12.53919302
# Validation score: -0.212440
# Iteration 24, loss = 11.57667795
# Validation score: -0.132480
# Iteration 25, loss = 10.80380783
# Validation score: -0.068308
# Iteration 26, loss = 10.16008118
# Validation score: -0.020175
# Iteration 27, loss = 9.67872218
# Validation score: 0.013237
# Iteration 28, loss = 9.26478702
# Validation score: 0.034129
# Iteration 29, loss = 8.97744666
# Validation score: 0.045322
# Iteration 30, loss = 8.78086588
# Validation score: 0.049010
# Iteration 31, loss = 8.63637580
# Validation score: 0.047546
# Iteration 32, loss = 8.56403600
# Validation score: 0.042796
# Iteration 33, loss = 8.52023784
# Validation score: 0.037126
# Iteration 34, loss = 8.47773455
# Validation score: 0.031377
# Iteration 35, loss = 8.46366601
# Validation score: 0.026250
# Iteration 36, loss = 8.43754690
# Validation score: 0.022969
# Iteration 37, loss = 8.41382389
# Validation score: 0.020924
# Iteration 38, loss = 8.37795075
# Validation score: 0.020877
# Iteration 39, loss = 8.33399807
# Validation score: 0.022192
# Iteration 40, loss = 8.28299714
# Validation score: 0.024687
# Iteration 41, loss = 8.23052416
# Validation score: 0.028411
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 67.36565268
# Validation score: -4.352043
# Iteration 2, loss = 64.35357523
# Validation score: -4.143508
# Iteration 3, loss = 61.51583660
# Validation score: -3.937866
# Iteration 4, loss = 58.67428654
# Validation score: -3.737556
# Iteration 5, loss = 55.94619897
# Validation score: -3.541117
# Iteration 6, loss = 53.26456160
# Validation score: -3.346674
# Iteration 7, loss = 50.63663664
# Validation score: -3.154978
# Iteration 8, loss = 48.02404760
# Validation score: -2.966595
# Iteration 9, loss = 45.54898126
# Validation score: -2.780511
# Iteration 10, loss = 43.04695221
# Validation score: -2.594715
# Iteration 11, loss = 40.61466900
# Validation score: -2.409105
# Iteration 12, loss = 38.22652557
# Validation score: -2.225939
# Iteration 13, loss = 35.88066525
# Validation score: -2.045187
# Iteration 14, loss = 33.62917456
# Validation score: -1.867724
# Iteration 15, loss = 31.35004575
# Validation score: -1.693316
# Iteration 16, loss = 29.16366438
# Validation score: -1.521378
# Iteration 17, loss = 27.04098562
# Validation score: -1.353551
# Iteration 18, loss = 25.01648272
# Validation score: -1.189498
# Iteration 19, loss = 23.08784870
# Validation score: -1.030598
# Iteration 20, loss = 21.21217530
# Validation score: -0.879000
# Iteration 21, loss = 19.45128337
# Validation score: -0.734939
# Iteration 22, loss = 17.82275998
# Validation score: -0.598554
# Iteration 23, loss = 16.30783411
# Validation score: -0.471136
# Iteration 24, loss = 14.93683263
# Validation score: -0.353132
# Iteration 25, loss = 13.72316028
# Validation score: -0.245580
# Iteration 26, loss = 12.61867282
# Validation score: -0.148941
# Iteration 27, loss = 11.65208414
# Validation score: -0.062910
# Iteration 28, loss = 10.86096687
# Validation score: 0.012686
# Iteration 29, loss = 10.18205969
# Validation score: 0.078306
# Iteration 30, loss = 9.60182319
# Validation score: 0.134418
# Iteration 31, loss = 9.21481676
# Validation score: 0.182035
# Iteration 32, loss = 8.88435477
# Validation score: 0.221063
# Iteration 33, loss = 8.62694294
# Validation score: 0.252719
# Iteration 34, loss = 8.49732475
# Validation score: 0.278280
# Iteration 35, loss = 8.38568890
# Validation score: 0.298066
# Iteration 36, loss = 8.31543545
# Validation score: 0.313281
# Iteration 37, loss = 8.27293220
# Validation score: 0.324642
# Iteration 38, loss = 8.23042634
# Validation score: 0.333153
# Iteration 39, loss = 8.20592756
# Validation score: 0.339865
# Iteration 40, loss = 8.18485342
# Validation score: 0.345197
# Iteration 41, loss = 8.15370546
# Validation score: 0.349362
# Iteration 42, loss = 8.11655548
# Validation score: 0.352801
# Iteration 43, loss = 8.07304148
# Validation score: 0.355722
# Iteration 44, loss = 8.03238875
# Validation score: 0.357808
# Iteration 45, loss = 7.98173615
# Validation score: 0.358841
# Iteration 46, loss = 7.93180245
# Validation score: 0.359731
# Iteration 47, loss = 7.88052499
# Validation score: 0.360274
# Iteration 48, loss = 7.83230961
# Validation score: 0.360376
# Iteration 49, loss = 7.78656527
# Validation score: 0.360117
# Iteration 50, loss = 7.74846020
# Validation score: 0.359895
# Iteration 51, loss = 7.70767166
# Validation score: 0.359552
# Iteration 52, loss = 7.68272571
# Validation score: 0.359564
# Iteration 53, loss = 7.64313690
# Validation score: 0.360290
# Iteration 54, loss = 7.61849196
# Validation score: 0.361174
# Iteration 55, loss = 7.59128129
# Validation score: 0.362292
# Iteration 56, loss = 7.56167353
# Validation score: 0.364121
# Iteration 57, loss = 7.53294472
# Validation score: 0.365914
# Iteration 58, loss = 7.50807849
# Validation score: 0.368138
# Iteration 59, loss = 7.47954512
# Validation score: 0.370421
# Iteration 60, loss = 7.46032140
# Validation score: 0.372507
# Iteration 61, loss = 7.42947199
# Validation score: 0.374387
# Iteration 62, loss = 7.40500030
# Validation score: 0.376180
# Iteration 63, loss = 7.38139665
# Validation score: 0.378194
# Iteration 64, loss = 7.35557223
# Validation score: 0.380072
# Iteration 65, loss = 7.33345304
# Validation score: 0.382397
# Iteration 66, loss = 7.30757209
# Validation score: 0.384469
# Iteration 67, loss = 7.28413540
# Validation score: 0.386260
# Iteration 68, loss = 7.26577518
# Validation score: 0.387899
# Iteration 69, loss = 7.24108000
# Validation score: 0.388985
# Iteration 70, loss = 7.21867653
# Validation score: 0.390074
# Iteration 71, loss = 7.19769851
# Validation score: 0.390784
# Iteration 72, loss = 7.17688082
# Validation score: 0.391044
# Iteration 73, loss = 7.15970012
# Validation score: 0.391382
# Iteration 74, loss = 7.13624170
# Validation score: 0.392044
# Iteration 75, loss = 7.11831092
# Validation score: 0.392489
# Iteration 76, loss = 7.09837326
# Validation score: 0.393084
# Iteration 77, loss = 7.08005493
# Validation score: 0.393910
# Iteration 78, loss = 7.06026900
# Validation score: 0.395169
# Iteration 79, loss = 7.04194053
# Validation score: 0.396241
# Iteration 80, loss = 7.02469459
# Validation score: 0.396936
# Iteration 81, loss = 7.00650607
# Validation score: 0.397348
# Iteration 82, loss = 6.98789896
# Validation score: 0.398441
# Iteration 83, loss = 6.97064860
# Validation score: 0.399690
# Iteration 84, loss = 6.95461725
# Validation score: 0.400855
# Iteration 85, loss = 6.93788524
# Validation score: 0.401931
# Iteration 86, loss = 6.92203667
# Validation score: 0.402453
# Iteration 87, loss = 6.90516516
# Validation score: 0.402551
# Iteration 88, loss = 6.88823000
# Validation score: 0.402390
# Iteration 89, loss = 6.87351059
# Validation score: 0.402062
# Iteration 90, loss = 6.85775984
# Validation score: 0.401960
# Iteration 91, loss = 6.84094877
# Validation score: 0.401823
# Iteration 92, loss = 6.82472752
# Validation score: 0.401942
# Iteration 93, loss = 6.81167504
# Validation score: 0.402450
# Iteration 94, loss = 6.79563686
# Validation score: 0.403064
# Iteration 95, loss = 6.78037625
# Validation score: 0.403653
# Iteration 96, loss = 6.76580194
# Validation score: 0.403998
# Iteration 97, loss = 6.75182655
# Validation score: 0.404200
# Iteration 98, loss = 6.73601794
# Validation score: 0.404502
# Iteration 99, loss = 6.72156785
# Validation score: 0.405031
# Iteration 100, loss = 6.70727326
# Validation score: 0.405525
# Iteration 101, loss = 6.69541321
# Validation score: 0.406261
# Iteration 102, loss = 6.67974028
# Validation score: 0.406785
# Iteration 103, loss = 6.66645907
# Validation score: 0.407189
# Iteration 104, loss = 6.65152949
# Validation score: 0.407324
# Iteration 105, loss = 6.63748487
# Validation score: 0.407570
# Iteration 106, loss = 6.62608737
# Validation score: 0.407927
# Iteration 107, loss = 6.61182589
# Validation score: 0.408573
# Iteration 108, loss = 6.59946551
# Validation score: 0.409037
# Iteration 109, loss = 6.58713956
# Validation score: 0.409207
# Iteration 110, loss = 6.57334163
# Validation score: 0.408655
# Iteration 111, loss = 6.56130441
# Validation score: 0.408169
# Iteration 112, loss = 6.54712028
# Validation score: 0.408059
# Iteration 113, loss = 6.53540557
# Validation score: 0.407960
# Iteration 114, loss = 6.52215827
# Validation score: 0.407736
# Iteration 115, loss = 6.50908409
# Validation score: 0.407763
# Iteration 116, loss = 6.49699113
# Validation score: 0.408260
# Iteration 117, loss = 6.48375140
# Validation score: 0.408332
# Iteration 118, loss = 6.47145469
# Validation score: 0.408265
# Iteration 119, loss = 6.45776650
# Validation score: 0.408376
# Iteration 120, loss = 6.44491685
# Validation score: 0.408523
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 55.61373815
# Validation score: -1.567777
# Iteration 2, loss = 30.11963690
# Validation score: -0.254228
# Iteration 3, loss = 13.25680791
# Validation score: -0.039586
# Iteration 4, loss = 9.91987963
# Validation score: -0.823952
# Iteration 5, loss = 15.65569650
# Validation score: -0.952197
# Iteration 6, loss = 14.78625561
# Validation score: -0.479400
# Iteration 7, loss = 10.08562812
# Validation score: -0.107449
# Iteration 8, loss = 8.15242670
# Validation score: -0.003505
# Iteration 9, loss = 8.36439245
# Validation score: -0.033102
# Iteration 10, loss = 9.44354213
# Validation score: -0.062392
# Iteration 11, loss = 9.57894582
# Validation score: -0.054241
# Iteration 12, loss = 8.83271951
# Validation score: -0.046395
# Iteration 13, loss = 7.76364088
# Validation score: -0.086249
# Iteration 14, loss = 7.35844804
# Validation score: -0.181029
# Iteration 15, loss = 7.37267809
# Validation score: -0.267929
# Iteration 16, loss = 7.68019819
# Validation score: -0.287099
# Iteration 17, loss = 7.62916118
# Validation score: -0.235567
# Iteration 18, loss = 7.22082788
# Validation score: -0.163569
# Iteration 19, loss = 6.91238122
# Validation score: -0.112290
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Best cross-validation score: -18.93226671618034

# %%
import pandas as pd
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Load the dataset
data = pd.read_csv('/Users/jamescheng/Desktop/WASHU/CSE 514/student+performance/student/student-mat.csv', delimiter=';')

# Drop 'G1' and 'G2' columns
data = data.drop(['G1', 'G2'], axis=1)

# Separate the features and the target variable
X = data.drop('G3', axis=1)
y = data['G3']

# Identifying categorical and numerical columns for preprocessing
categorical_columns = X.select_dtypes(include=['object', 'category']).columns
numerical_columns = X.select_dtypes(include=['int', 'float']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns),
        ('scaler', StandardScaler(), numerical_columns)
    ],
    remainder='passthrough'
)

# Creating a modeling pipeline with XGBoost
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('xgb', XGBRegressor(objective='reg:squarederror', random_state=42))
])

# If you want to fine-tune hyperparameters, define a parameter grid
param_grid = {
    'xgb__learning_rate': [0.01, 0.1, 0.2, 0.3, 0.4],
}

# Setting up GridSearchCV for hyperparameter tuning (optional)
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

# Printing the best parameters and cross-validation score
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'xgb__learning_rate': 0.01}
# Best cross-validation score: -17.960239066574957
