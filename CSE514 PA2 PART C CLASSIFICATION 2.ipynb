# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the data
file_path = '../student-mat.csv'
data = pd.read_csv(file_path, delimiter=';')

# %%
# Binary classification problem 1: Predicting high/low grade based on median G3 value
median_g3 = data['G3'].median()
data['high_performance'] = (data['G3'] > median_g3).astype(int)

X = data.drop('high_performance', axis=1)
y = data['high_performance']

# Split dataset into training set and validation set (adjust test_size and random_state as needed)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
print("Training set shape:", X_train.shape, y_train.shape)
print("Validation set shape:", X_val.shape, y_val.shape)

train_data = pd.concat([X_train, y_train], axis=1)
train_data.to_csv('train_data_problem1.csv', index=False)

# Save validation set
val_data = pd.concat([X_val, y_val], axis=1)
val_data.to_csv('val_data_problem1.csv', index=False)
# Out:
# Training set shape: (355, 33) (355,)
# Validation set shape: (40, 33) (40,)

# %%
data = pd.read_csv(file_path, delimiter=';')

# One-hot encoding for categorical variables except for our binary targets
features = pd.get_dummies(data.drop(['G3', 'school', 'internet'], axis=1))
# Binary classification problem 2: Predicting school (already binary, just encode directly)
data['school_binary'] = (data['school'] == 'GP').astype(int)

X = data.drop('school_binary', axis=1)
y = data['school_binary']

# Split dataset into training set and validation set (adjust test_size and random_state as needed)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
print("Training set shape:", X_train.shape, y_train.shape)
print("Validation set shape:", X_val.shape, y_val.shape)

train_data = pd.concat([X_train, y_train], axis=1)
train_data.to_csv('train_data_problem2.csv', index=False)

# Save validation set
val_data = pd.concat([X_val, y_val], axis=1)
val_data.to_csv('val_data_problem2.csv', index=False)
# Out:
# Training set shape: (355, 33) (355,)
# Validation set shape: (40, 33) (40,)

# %%
 # Binary classification problem 3: Predicting internet access
data['internet_binary'] = (data['internet'] == 'yes').astype(int)
# One-hot encoding for categorical variables except for our binary targets
features = pd.get_dummies(data.drop(['G3', 'school', 'internet'], axis=1))


X = data.drop('internet_binary', axis=1)
y = data['internet_binary']

# Split dataset into training set and validation set (adjust test_size and random_state as needed)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)
print("Training set shape:", X_train.shape, y_train.shape)
print("Validation set shape:", X_val.shape, y_val.shape)

train_data = pd.concat([X_train, y_train], axis=1)
train_data.to_csv('train_data_problem3.csv', index=False)

# Save validation set
val_data = pd.concat([X_val, y_val], axis=1)
val_data.to_csv('val_data_problem3.csv', index=False)
# Out:
# Training set shape: (355, 34) (355,)
# Validation set shape: (40, 34) (40,)

# %%
# Ridge Regression

import pandas as pd
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge

# Load the dataset
file_path = './train_data_problem2.csv'
data = pd.read_csv(file_path, delimiter=',')
print(data.head())
# # One-hot encoding for categorical variables except for our binary targets
# features = pd.get_dummies(data.drop(['G3', 'school', 'internet'], axis=1))

X = data.drop('school_binary', axis=1)
y = data['school_binary']

# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating the Ridge regression model pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('ridge_regression', Ridge())
])

# Setting up parameter grid for hyperparameter tuning
param_grid = {'ridge_regression__alpha': [0.01, 0.1, 1, 10, 100]}  # alpha is equivalent to λ

# Setting up GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   15       R     GT3       T     1     1     other     other
# 1     GP   F   15       U     GT3       T     1     1     other  services
# 2     GP   F   17       U     GT3       T     4     4   teacher   teacher
# 3     GP   M   16       U     LE3       T     2     2  services  services
# 4     GP   M   16       R     GT3       T     2     2   at_home     other
#
#    ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 school_binary
# 0  ...        3     4     2     4       5        2   8   6   5             1
# 1  ...        4     2     1     2       5        0   8  11  11             1
# 2  ...        3     3     1     2       4        4  14  14  14             1
# 3  ...        3     3     2     2       2        8   9   9   9             1
# 4  ...        2     2     1     2       3        2  17  15  15             1
#
# [5 rows x 34 columns]
# Best parameters: {'ridge_regression__alpha': 0.01}
# Best cross-validation score: -7.4397826374978385e-09

# %%
# SVR
from sklearn.svm import SVR  # Using SVR for regression

# Load the dataset with the correct delimiter
data = pd.read_csv('./train_data_problem2.csv', delimiter=',')


# Separate the features and the target variable
X = data.drop('school_binary', axis=1)
y = data['school_binary']

# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating the SVM model pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('svm', SVR(C=1.0))
])

# Setting up parameter grid for hyperparameter tuning (C values to test)
param_grid = {'svm__C': [0.1, 1, 10, 100, 1000]}

# Setting up GridSearchCV for 5-fold cross-validation and hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'svm__C': 100}
# Best cross-validation score: -0.009191198986158142

# %%
# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
# Load the dataset
data = pd.read_csv('./train_data_problem2.csv', delimiter=',')


# Separate the features and the target variable
X = data.drop('school_binary', axis=1)
y = data['school_binary']


# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating the model pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('random_forest', RandomForestRegressor())
])

# Define the parameter grid to test different hyperparameter values
param_grid = {
    'random_forest__n_estimators': [10, 50, 100, 200, 500]
}

# Setting Up GridSearchCV to find the best model configuration using 5-fold cross-validation
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'random_forest__n_estimators': 10}
# Best cross-validation score: 0.0

# %%
# KNN
from sklearn.neighbors import KNeighborsRegressor 

# Load the dataset
data = pd.read_csv('./train_data_problem2.csv', delimiter=',')

X = data.drop('school_binary', axis=1)
y = data['school_binary']

# Identifying categorical columns for one-hot encoding
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'
)

# Creating a modeling pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('knn', KNeighborsRegressor())
])

# Define the parameter grid to test different values for n_neighbors
param_grid = {'knn__n_neighbors': [1, 3, 5, 7, 9]}

# Setting up GridSearchCV for 5-fold cross-validation and hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'knn__n_neighbors': 5}
# Best cross-validation score: -0.07549295774647888

# %%
# 
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import OneHotEncoder, StandardScaler


# Load the dataset
data = pd.read_csv('./train_data_problem2.csv', delimiter=',')

X = data.drop('school_binary', axis=1)
y = data['school_binary']


# Identifying categorical columns and numerical columns for preprocessing
categorical_columns = X.select_dtypes(include=['object', 'category']).columns
numerical_columns = X.select_dtypes(include=['int', 'float']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns),
        ('scaler', StandardScaler(), numerical_columns)
    ],
    remainder='passthrough'
)

model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('ann', MLPRegressor(random_state=42, max_iter=1000, verbose=True, early_stopping=True))
])

# Define the parameter grid to test different learning rates
param_grid = {
    'ann__learning_rate_init': [0.1, 0.01, 0.001]
}

# Setting up GridSearchCV for 5-fold cross-validation and hyperparameter tuning
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

# Printing the best cross-validation score
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Iteration 1, loss = 33.24129597
# Validation score: -119.769549
# Iteration 2, loss = 5.88594222
# Validation score: -6.071318
# Iteration 3, loss = 0.60612405
# Validation score: -7.999409
# Iteration 4, loss = 0.71396912
# Validation score: -8.544018
# Iteration 5, loss = 0.75300629
# Validation score: -8.829304
# Iteration 6, loss = 0.77191917
# Validation score: -8.629606
# Iteration 7, loss = 0.78613807
# Validation score: -8.306687
# Iteration 8, loss = 0.75936833
# Validation score: -7.927530
# Iteration 9, loss = 0.71556695
# Validation score: -7.263875
# Iteration 10, loss = 0.65013388
# Validation score: -5.939352
# Iteration 11, loss = 0.54195711
# Validation score: -3.724543
# Iteration 12, loss = 0.38393698
# Validation score: -2.220179
# Iteration 13, loss = 0.25707614
# Validation score: -3.165592
# Iteration 14, loss = 0.23665719
# Validation score: -0.571419
# Iteration 15, loss = 0.13506934
# Validation score: 0.008036
# Iteration 16, loss = 0.07574562
# Validation score: -0.073360
# Iteration 17, loss = 0.05188290
# Validation score: -0.378255
# Iteration 18, loss = 0.09307109
# Validation score: -0.822426
# Iteration 19, loss = 0.07830948
# Validation score: 0.348797
# Iteration 20, loss = 0.04385091
# Validation score: 0.406853
# Iteration 21, loss = 0.03269628
# Validation score: -0.133869
# Iteration 22, loss = 0.04557338
# Validation score: 0.261494
# Iteration 23, loss = 0.04249013
# Validation score: 0.284901
# Iteration 24, loss = 0.03179068
# Validation score: 0.421876
# Iteration 25, loss = 0.02695256
# Validation score: 0.435832
# Iteration 26, loss = 0.02751469
# Validation score: 0.195562
# Iteration 27, loss = 0.03135160
# Validation score: 0.474297
# Iteration 28, loss = 0.02613565
# Validation score: 0.507782
# Iteration 29, loss = 0.02072222
# Validation score: 0.306321
# Iteration 30, loss = 0.02609204
# Validation score: 0.535610
# Iteration 31, loss = 0.02091676
# Validation score: 0.544077
# Iteration 32, loss = 0.01793246
# Validation score: 0.487503
# Iteration 33, loss = 0.01787056
# Validation score: 0.585790
# Iteration 34, loss = 0.01668882
# Validation score: 0.565670
# Iteration 35, loss = 0.01461200
# Validation score: 0.585008
# Iteration 36, loss = 0.01368411
# Validation score: 0.629078
# Iteration 37, loss = 0.01337819
# Validation score: 0.608682
# Iteration 38, loss = 0.01253747
# Validation score: 0.631997
# Iteration 39, loss = 0.01177702
# Validation score: 0.673374
# Iteration 40, loss = 0.01125727
# Validation score: 0.657220
# Iteration 41, loss = 0.01068843
# Validation score: 0.676871
# Iteration 42, loss = 0.01000105
# Validation score: 0.711948
# Iteration 43, loss = 0.00937663
# Validation score: 0.723015
# Iteration 44, loss = 0.00881468
# Validation score: 0.730241
# Iteration 45, loss = 0.00832312
# Validation score: 0.759739
# Iteration 46, loss = 0.00798049
# Validation score: 0.761706
# Iteration 47, loss = 0.00746483
# Validation score: 0.771203
# Iteration 48, loss = 0.00697717
# Validation score: 0.803265
# Iteration 49, loss = 0.00667858
# Validation score: 0.802630
# Iteration 50, loss = 0.00628439
# Validation score: 0.820099
# Iteration 51, loss = 0.00571879
# Validation score: 0.843187
# Iteration 52, loss = 0.00572093
# Validation score: 0.842493
# Iteration 53, loss = 0.00511735
# Validation score: 0.855941
# Iteration 54, loss = 0.00474983
# Validation score: 0.875053
# Iteration 55, loss = 0.00446976
# Validation score: 0.879680
# Iteration 56, loss = 0.00407656
# Validation score: 0.891015
# Iteration 57, loss = 0.00376902
# Validation score: 0.902904
# Iteration 58, loss = 0.00353517
# Validation score: 0.906580
# Iteration 59, loss = 0.00331616
# Validation score: 0.915865
# Iteration 60, loss = 0.00301182
# Validation score: 0.926882
# Iteration 61, loss = 0.00289224
# Validation score: 0.931174
# Iteration 62, loss = 0.00264531
# Validation score: 0.936158
# Iteration 63, loss = 0.00254033
# Validation score: 0.946708
# Iteration 64, loss = 0.00227894
# Validation score: 0.951716
# Iteration 65, loss = 0.00207443
# Validation score: 0.955789
# Iteration 66, loss = 0.00199167
# Validation score: 0.962464
# Iteration 67, loss = 0.00186028
# Validation score: 0.966941
# Iteration 68, loss = 0.00170104
# Validation score: 0.969573
# Iteration 69, loss = 0.00166639
# Validation score: 0.974081
# Iteration 70, loss = 0.00150355
# Validation score: 0.975786
# Iteration 71, loss = 0.00147524
# Validation score: 0.978882
# Iteration 72, loss = 0.00134814
# Validation score: 0.980896
# Iteration 73, loss = 0.00128165
# Validation score: 0.982489
# Iteration 74, loss = 0.00123861
# Validation score: 0.984273
# Iteration 75, loss = 0.00117554
# Validation score: 0.986073
# Iteration 76, loss = 0.00112825
# Validation score: 0.987530
# Iteration 77, loss = 0.00108442
# Validation score: 0.988655
# Iteration 78, loss = 0.00104199
# Validation score: 0.989851
# Iteration 79, loss = 0.00101247
# Validation score: 0.990858
# Iteration 80, loss = 0.00097602
# Validation score: 0.991436
# Iteration 81, loss = 0.00097216
# Validation score: 0.992553
# Iteration 82, loss = 0.00092856
# Validation score: 0.993010
# Iteration 83, loss = 0.00092190
# Validation score: 0.993737
# Iteration 84, loss = 0.00089529
# Validation score: 0.994314
# Iteration 85, loss = 0.00087538
# Validation score: 0.994807
# Iteration 86, loss = 0.00085980
# Validation score: 0.995353
# Iteration 87, loss = 0.00084197
# Validation score: 0.995757
# Iteration 88, loss = 0.00083079
# Validation score: 0.996119
# Iteration 89, loss = 0.00082045
# Validation score: 0.996460
# Iteration 90, loss = 0.00080932
# Validation score: 0.996716
# Iteration 91, loss = 0.00080505
# Validation score: 0.996990
# Iteration 92, loss = 0.00079397
# Validation score: 0.997149
# Iteration 93, loss = 0.00078732
# Validation score: 0.997375
# Iteration 94, loss = 0.00077848
# Validation score: 0.997522
# Iteration 95, loss = 0.00077478
# Validation score: 0.997665
# Iteration 96, loss = 0.00076872
# Validation score: 0.997804
# Iteration 97, loss = 0.00076271
# Validation score: 0.997907
# Iteration 98, loss = 0.00076128
# Validation score: 0.998040
# Iteration 99, loss = 0.00075310
# Validation score: 0.998152
# Iteration 100, loss = 0.00074913
# Validation score: 0.998258
# Iteration 101, loss = 0.00074508
# Validation score: 0.998355
# Iteration 102, loss = 0.00074145
# Validation score: 0.998434
# Iteration 103, loss = 0.00073890
# Validation score: 0.998523
# Iteration 104, loss = 0.00073558
# Validation score: 0.998594
# Iteration 105, loss = 0.00073272
# Validation score: 0.998654
# Iteration 106, loss = 0.00073035
# Validation score: 0.998733
# Iteration 107, loss = 0.00072751
# Validation score: 0.998796
# Iteration 108, loss = 0.00072467
# Validation score: 0.998843
# Iteration 109, loss = 0.00072278
# Validation score: 0.998903
# Iteration 110, loss = 0.00071988
# Validation score: 0.998958
# Iteration 111, loss = 0.00071755
# Validation score: 0.999005
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 34.62182494
# Validation score: -82.303817
# Iteration 2, loss = 5.56022350
# Validation score: -3.530608
# Iteration 3, loss = 0.59318340
# Validation score: -4.765754
# Iteration 4, loss = 0.70275688
# Validation score: -4.954593
# Iteration 5, loss = 0.74446528
# Validation score: -5.101644
# Iteration 6, loss = 0.76084272
# Validation score: -5.079267
# Iteration 7, loss = 0.76140294
# Validation score: -4.952049
# Iteration 8, loss = 0.73535882
# Validation score: -4.668709
# Iteration 9, loss = 0.69713776
# Validation score: -4.459951
# Iteration 10, loss = 0.66605256
# Validation score: -4.467491
# Iteration 11, loss = 0.61814873
# Validation score: -3.996879
# Iteration 12, loss = 0.53809360
# Validation score: -3.273319
# Iteration 13, loss = 0.46190978
# Validation score: -2.539863
# Iteration 14, loss = 0.41243481
# Validation score: -2.047051
# Iteration 15, loss = 0.33749512
# Validation score: -2.148741
# Iteration 16, loss = 0.30426020
# Validation score: -1.193911
# Iteration 17, loss = 0.25523644
# Validation score: -0.884073
# Iteration 18, loss = 0.19899543
# Validation score: -0.897889
# Iteration 19, loss = 0.16782040
# Validation score: -0.482064
# Iteration 20, loss = 0.15160321
# Validation score: -0.715977
# Iteration 21, loss = 0.12657184
# Validation score: -0.171708
# Iteration 22, loss = 0.12524209
# Validation score: -0.196503
# Iteration 23, loss = 0.09675237
# Validation score: 0.180628
# Iteration 24, loss = 0.07619357
# Validation score: 0.231589
# Iteration 25, loss = 0.07123790
# Validation score: 0.133870
# Iteration 26, loss = 0.06304265
# Validation score: 0.281668
# Iteration 27, loss = 0.05153831
# Validation score: 0.070704
# Iteration 28, loss = 0.04733267
# Validation score: 0.191403
# Iteration 29, loss = 0.06886176
# Validation score: -0.077986
# Iteration 30, loss = 0.05108959
# Validation score: 0.318987
# Iteration 31, loss = 0.04740523
# Validation score: 0.062837
# Iteration 32, loss = 0.04199018
# Validation score: 0.357855
# Iteration 33, loss = 0.03890553
# Validation score: 0.177272
# Iteration 34, loss = 0.03578011
# Validation score: 0.341672
# Iteration 35, loss = 0.03193475
# Validation score: 0.346896
# Iteration 36, loss = 0.03045041
# Validation score: 0.291892
# Iteration 37, loss = 0.02929267
# Validation score: 0.403229
# Iteration 38, loss = 0.02834992
# Validation score: 0.253297
# Iteration 39, loss = 0.02818452
# Validation score: 0.442676
# Iteration 40, loss = 0.02820360
# Validation score: 0.377484
# Iteration 41, loss = 0.02338334
# Validation score: 0.448173
# Iteration 42, loss = 0.02205868
# Validation score: 0.439299
# Iteration 43, loss = 0.02103274
# Validation score: 0.486878
# Iteration 44, loss = 0.02026079
# Validation score: 0.461174
# Iteration 45, loss = 0.01970360
# Validation score: 0.541307
# Iteration 46, loss = 0.01995704
# Validation score: 0.500069
# Iteration 47, loss = 0.01860223
# Validation score: 0.549132
# Iteration 48, loss = 0.01732296
# Validation score: 0.588890
# Iteration 49, loss = 0.01692183
# Validation score: 0.535919
# Iteration 50, loss = 0.01664619
# Validation score: 0.627345
# Iteration 51, loss = 0.01560301
# Validation score: 0.598925
# Iteration 52, loss = 0.01481460
# Validation score: 0.644889
# Iteration 53, loss = 0.01390631
# Validation score: 0.665033
# Iteration 54, loss = 0.01328147
# Validation score: 0.653759
# Iteration 55, loss = 0.01308315
# Validation score: 0.702021
# Iteration 56, loss = 0.01257186
# Validation score: 0.694483
# Iteration 57, loss = 0.01205045
# Validation score: 0.714860
# Iteration 58, loss = 0.01148825
# Validation score: 0.736163
# Iteration 59, loss = 0.01129938
# Validation score: 0.725905
# Iteration 60, loss = 0.01084859
# Validation score: 0.753050
# Iteration 61, loss = 0.01042514
# Validation score: 0.757372
# Iteration 62, loss = 0.00998867
# Validation score: 0.763675
# Iteration 63, loss = 0.00973124
# Validation score: 0.778568
# Iteration 64, loss = 0.00929161
# Validation score: 0.778203
# Iteration 65, loss = 0.00916775
# Validation score: 0.797912
# Iteration 66, loss = 0.00873227
# Validation score: 0.803453
# Iteration 67, loss = 0.00844550
# Validation score: 0.810604
# Iteration 68, loss = 0.00812587
# Validation score: 0.821079
# Iteration 69, loss = 0.00799519
# Validation score: 0.824202
# Iteration 70, loss = 0.00763967
# Validation score: 0.831657
# Iteration 71, loss = 0.00737328
# Validation score: 0.839434
# Iteration 72, loss = 0.00719620
# Validation score: 0.844197
# Iteration 73, loss = 0.00692376
# Validation score: 0.848607
# Iteration 74, loss = 0.00668599
# Validation score: 0.855094
# Iteration 75, loss = 0.00656947
# Validation score: 0.858513
# Iteration 76, loss = 0.00629503
# Validation score: 0.863657
# Iteration 77, loss = 0.00606208
# Validation score: 0.868574
# Iteration 78, loss = 0.00590274
# Validation score: 0.872435
# Iteration 79, loss = 0.00570475
# Validation score: 0.877309
# Iteration 80, loss = 0.00550416
# Validation score: 0.881432
# Iteration 81, loss = 0.00541630
# Validation score: 0.885737
# Iteration 82, loss = 0.00519934
# Validation score: 0.890071
# Iteration 83, loss = 0.00502008
# Validation score: 0.893460
# Iteration 84, loss = 0.00492048
# Validation score: 0.896873
# Iteration 85, loss = 0.00480917
# Validation score: 0.900373
# Iteration 86, loss = 0.00473493
# Validation score: 0.904352
# Iteration 87, loss = 0.00451700
# Validation score: 0.906839
# Iteration 88, loss = 0.00442000
# Validation score: 0.908893
# Iteration 89, loss = 0.00435864
# Validation score: 0.912747
# Iteration 90, loss = 0.00419339
# Validation score: 0.916067
# Iteration 91, loss = 0.00402208
# Validation score: 0.918745
# Iteration 92, loss = 0.00392049
# Validation score: 0.921468
# Iteration 93, loss = 0.00377965
# Validation score: 0.922855
# Iteration 94, loss = 0.00374318
# Validation score: 0.926415
# Iteration 95, loss = 0.00358478
# Validation score: 0.928893
# Iteration 96, loss = 0.00345328
# Validation score: 0.930651
# Iteration 97, loss = 0.00339624
# Validation score: 0.933405
# Iteration 98, loss = 0.00328191
# Validation score: 0.935466
# Iteration 99, loss = 0.00318673
# Validation score: 0.937666
# Iteration 100, loss = 0.00308586
# Validation score: 0.939559
# Iteration 101, loss = 0.00303572
# Validation score: 0.941215
# Iteration 102, loss = 0.00297117
# Validation score: 0.943686
# Iteration 103, loss = 0.00286980
# Validation score: 0.945598
# Iteration 104, loss = 0.00279218
# Validation score: 0.947324
# Iteration 105, loss = 0.00269309
# Validation score: 0.948643
# Iteration 106, loss = 0.00267355
# Validation score: 0.950194
# Iteration 107, loss = 0.00260176
# Validation score: 0.952363
# Iteration 108, loss = 0.00250045
# Validation score: 0.954169
# Iteration 109, loss = 0.00242217
# Validation score: 0.955816
# Iteration 110, loss = 0.00235823
# Validation score: 0.957423
# Iteration 111, loss = 0.00229644
# Validation score: 0.958976
# Iteration 112, loss = 0.00223227
# Validation score: 0.960446
# Iteration 113, loss = 0.00217375
# Validation score: 0.961910
# Iteration 114, loss = 0.00211137
# Validation score: 0.963294
# Iteration 115, loss = 0.00205690
# Validation score: 0.964600
# Iteration 116, loss = 0.00200840
# Validation score: 0.965945
# Iteration 117, loss = 0.00195328
# Validation score: 0.967176
# Iteration 118, loss = 0.00190245
# Validation score: 0.968349
# Iteration 119, loss = 0.00185692
# Validation score: 0.969522
# Iteration 120, loss = 0.00180908
# Validation score: 0.970642
# Iteration 121, loss = 0.00176653
# Validation score: 0.971789
# Iteration 122, loss = 0.00172506
# Validation score: 0.972882
# Iteration 123, loss = 0.00168296
# Validation score: 0.973921
# Iteration 124, loss = 0.00164232
# Validation score: 0.974929
# Iteration 125, loss = 0.00160157
# Validation score: 0.975961
# Iteration 126, loss = 0.00156708
# Validation score: 0.976938
# Iteration 127, loss = 0.00152717
# Validation score: 0.977880
# Iteration 128, loss = 0.00149191
# Validation score: 0.978793
# Iteration 129, loss = 0.00145586
# Validation score: 0.979614
# Iteration 130, loss = 0.00142412
# Validation score: 0.980546
# Iteration 131, loss = 0.00139119
# Validation score: 0.981403
# Iteration 132, loss = 0.00135665
# Validation score: 0.982243
# Iteration 133, loss = 0.00132572
# Validation score: 0.983040
# Iteration 134, loss = 0.00129485
# Validation score: 0.983828
# Iteration 135, loss = 0.00126648
# Validation score: 0.984562
# Iteration 136, loss = 0.00123893
# Validation score: 0.985237
# Iteration 137, loss = 0.00121258
# Validation score: 0.985876
# Iteration 138, loss = 0.00118823
# Validation score: 0.986469
# Iteration 139, loss = 0.00116392
# Validation score: 0.987051
# Iteration 140, loss = 0.00114415
# Validation score: 0.987597
# Iteration 141, loss = 0.00112088
# Validation score: 0.988134
# Iteration 142, loss = 0.00110097
# Validation score: 0.988643
# Iteration 143, loss = 0.00108214
# Validation score: 0.989141
# Iteration 144, loss = 0.00106384
# Validation score: 0.989612
# Iteration 145, loss = 0.00104593
# Validation score: 0.990037
# Iteration 146, loss = 0.00102800
# Validation score: 0.990458
# Iteration 147, loss = 0.00101292
# Validation score: 0.990856
# Iteration 148, loss = 0.00099645
# Validation score: 0.991239
# Iteration 149, loss = 0.00098143
# Validation score: 0.991614
# Iteration 150, loss = 0.00096702
# Validation score: 0.991986
# Iteration 151, loss = 0.00095256
# Validation score: 0.992350
# Iteration 152, loss = 0.00093945
# Validation score: 0.992705
# Iteration 153, loss = 0.00092541
# Validation score: 0.993038
# Iteration 154, loss = 0.00091257
# Validation score: 0.993359
# Iteration 155, loss = 0.00090027
# Validation score: 0.993666
# Iteration 156, loss = 0.00088913
# Validation score: 0.993956
# Iteration 157, loss = 0.00087744
# Validation score: 0.994231
# Iteration 158, loss = 0.00086692
# Validation score: 0.994493
# Iteration 159, loss = 0.00085633
# Validation score: 0.994741
# Iteration 160, loss = 0.00084713
# Validation score: 0.994978
# Iteration 161, loss = 0.00083747
# Validation score: 0.995202
# Iteration 162, loss = 0.00082902
# Validation score: 0.995416
# Iteration 163, loss = 0.00081998
# Validation score: 0.995621
# Iteration 164, loss = 0.00081257
# Validation score: 0.995823
# Iteration 165, loss = 0.00080451
# Validation score: 0.996017
# Iteration 166, loss = 0.00079690
# Validation score: 0.996202
# Iteration 167, loss = 0.00078904
# Validation score: 0.996383
# Iteration 168, loss = 0.00078214
# Validation score: 0.996553
# Iteration 169, loss = 0.00077549
# Validation score: 0.996723
# Iteration 170, loss = 0.00076860
# Validation score: 0.996881
# Iteration 171, loss = 0.00076230
# Validation score: 0.997037
# Iteration 172, loss = 0.00075580
# Validation score: 0.997186
# Iteration 173, loss = 0.00075048
# Validation score: 0.997333
# Iteration 174, loss = 0.00074451
# Validation score: 0.997463
# Iteration 175, loss = 0.00073874
# Validation score: 0.997594
# Iteration 176, loss = 0.00073359
# Validation score: 0.997720
# Iteration 177, loss = 0.00072824
# Validation score: 0.997843
# Iteration 178, loss = 0.00072348
# Validation score: 0.997959
# Iteration 179, loss = 0.00071894
# Validation score: 0.998072
# Iteration 180, loss = 0.00071421
# Validation score: 0.998176
# Iteration 181, loss = 0.00070986
# Validation score: 0.998275
# Iteration 182, loss = 0.00070562
# Validation score: 0.998368
# Iteration 183, loss = 0.00070185
# Validation score: 0.998457
# Iteration 184, loss = 0.00069816
# Validation score: 0.998540
# Iteration 185, loss = 0.00069460
# Validation score: 0.998619
# Iteration 186, loss = 0.00069114
# Validation score: 0.998692
# Iteration 187, loss = 0.00068800
# Validation score: 0.998762
# Iteration 188, loss = 0.00068491
# Validation score: 0.998829
# Iteration 189, loss = 0.00068205
# Validation score: 0.998892
# Iteration 190, loss = 0.00067914
# Validation score: 0.998952
# Iteration 191, loss = 0.00067648
# Validation score: 0.999010
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 33.09877218
# Validation score: -83.771107
# Iteration 2, loss = 6.36390603
# Validation score: -3.677315
# Iteration 3, loss = 0.61126908
# Validation score: -4.562875
# Iteration 4, loss = 0.75231067
# Validation score: -4.754149
# Iteration 5, loss = 0.76706170
# Validation score: -5.077961
# Iteration 6, loss = 0.77333659
# Validation score: -5.215315
# Iteration 7, loss = 0.76953508
# Validation score: -5.090966
# Iteration 8, loss = 0.75244542
# Validation score: -4.918139
# Iteration 9, loss = 0.72657823
# Validation score: -4.634922
# Iteration 10, loss = 0.69118194
# Validation score: -4.262941
# Iteration 11, loss = 0.64884017
# Validation score: -3.734257
# Iteration 12, loss = 0.59638389
# Validation score: -3.305801
# Iteration 13, loss = 0.54195132
# Validation score: -3.017075
# Iteration 14, loss = 0.48590059
# Validation score: -2.540887
# Iteration 15, loss = 0.40899992
# Validation score: -2.021191
# Iteration 16, loss = 0.33052223
# Validation score: -1.547259
# Iteration 17, loss = 0.24970093
# Validation score: -0.831898
# Iteration 18, loss = 0.20942170
# Validation score: -1.135636
# Iteration 19, loss = 0.15164337
# Validation score: -0.628816
# Iteration 20, loss = 0.17202136
# Validation score: -0.758368
# Iteration 21, loss = 0.11012856
# Validation score: -0.026253
# Iteration 22, loss = 0.09418846
# Validation score: -0.172201
# Iteration 23, loss = 0.06356404
# Validation score: 0.274917
# Iteration 24, loss = 0.05016721
# Validation score: 0.223635
# Iteration 25, loss = 0.03878015
# Validation score: 0.322757
# Iteration 26, loss = 0.03793297
# Validation score: 0.194238
# Iteration 27, loss = 0.03439747
# Validation score: 0.311529
# Iteration 28, loss = 0.02756305
# Validation score: 0.366902
# Iteration 29, loss = 0.03235833
# Validation score: 0.140273
# Iteration 30, loss = 0.03266000
# Validation score: 0.390969
# Iteration 31, loss = 0.02932877
# Validation score: 0.252649
# Iteration 32, loss = 0.02588034
# Validation score: 0.414757
# Iteration 33, loss = 0.02680544
# Validation score: 0.272238
# Iteration 34, loss = 0.02487540
# Validation score: 0.433173
# Iteration 35, loss = 0.02748170
# Validation score: 0.241334
# Iteration 36, loss = 0.02783159
# Validation score: 0.463414
# Iteration 37, loss = 0.02635961
# Validation score: 0.332459
# Iteration 38, loss = 0.02532998
# Validation score: 0.498579
# Iteration 39, loss = 0.02215923
# Validation score: 0.503362
# Iteration 40, loss = 0.02001080
# Validation score: 0.452908
# Iteration 41, loss = 0.02033238
# Validation score: 0.558364
# Iteration 42, loss = 0.01988342
# Validation score: 0.481444
# Iteration 43, loss = 0.01867263
# Validation score: 0.595288
# Iteration 44, loss = 0.01865502
# Validation score: 0.580158
# Iteration 45, loss = 0.01639648
# Validation score: 0.607967
# Iteration 46, loss = 0.01542516
# Validation score: 0.644249
# Iteration 47, loss = 0.01578372
# Validation score: 0.604679
# Iteration 48, loss = 0.01559450
# Validation score: 0.667457
# Iteration 49, loss = 0.01413934
# Validation score: 0.679415
# Iteration 50, loss = 0.01367524
# Validation score: 0.674101
# Iteration 51, loss = 0.01309171
# Validation score: 0.701062
# Iteration 52, loss = 0.01267846
# Validation score: 0.702472
# Iteration 53, loss = 0.01214984
# Validation score: 0.714220
# Iteration 54, loss = 0.01172482
# Validation score: 0.723494
# Iteration 55, loss = 0.01127793
# Validation score: 0.721583
# Iteration 56, loss = 0.01100175
# Validation score: 0.739834
# Iteration 57, loss = 0.01057983
# Validation score: 0.743367
# Iteration 58, loss = 0.01027495
# Validation score: 0.754433
# Iteration 59, loss = 0.00999598
# Validation score: 0.760048
# Iteration 60, loss = 0.00948519
# Validation score: 0.754417
# Iteration 61, loss = 0.00972106
# Validation score: 0.777401
# Iteration 62, loss = 0.00918531
# Validation score: 0.780940
# Iteration 63, loss = 0.00862986
# Validation score: 0.781407
# Iteration 64, loss = 0.00866289
# Validation score: 0.796658
# Iteration 65, loss = 0.00811356
# Validation score: 0.798190
# Iteration 66, loss = 0.00797338
# Validation score: 0.807452
# Iteration 67, loss = 0.00760031
# Validation score: 0.815339
# Iteration 68, loss = 0.00734979
# Validation score: 0.818274
# Iteration 69, loss = 0.00718469
# Validation score: 0.826261
# Iteration 70, loss = 0.00693050
# Validation score: 0.831236
# Iteration 71, loss = 0.00673611
# Validation score: 0.835549
# Iteration 72, loss = 0.00646492
# Validation score: 0.840244
# Iteration 73, loss = 0.00629295
# Validation score: 0.844607
# Iteration 74, loss = 0.00608849
# Validation score: 0.849571
# Iteration 75, loss = 0.00587024
# Validation score: 0.854218
# Iteration 76, loss = 0.00568334
# Validation score: 0.858377
# Iteration 77, loss = 0.00552555
# Validation score: 0.862612
# Iteration 78, loss = 0.00534716
# Validation score: 0.866364
# Iteration 79, loss = 0.00524997
# Validation score: 0.871413
# Iteration 80, loss = 0.00504752
# Validation score: 0.876026
# Iteration 81, loss = 0.00489904
# Validation score: 0.879914
# Iteration 82, loss = 0.00481376
# Validation score: 0.884538
# Iteration 83, loss = 0.00462484
# Validation score: 0.888135
# Iteration 84, loss = 0.00450208
# Validation score: 0.891131
# Iteration 85, loss = 0.00437965
# Validation score: 0.894480
# Iteration 86, loss = 0.00425417
# Validation score: 0.897704
# Iteration 87, loss = 0.00412408
# Validation score: 0.900627
# Iteration 88, loss = 0.00401667
# Validation score: 0.903871
# Iteration 89, loss = 0.00390533
# Validation score: 0.907336
# Iteration 90, loss = 0.00379837
# Validation score: 0.910731
# Iteration 91, loss = 0.00370648
# Validation score: 0.913807
# Iteration 92, loss = 0.00360918
# Validation score: 0.916679
# Iteration 93, loss = 0.00351354
# Validation score: 0.919531
# Iteration 94, loss = 0.00340437
# Validation score: 0.922219
# Iteration 95, loss = 0.00331933
# Validation score: 0.924974
# Iteration 96, loss = 0.00322743
# Validation score: 0.927415
# Iteration 97, loss = 0.00314430
# Validation score: 0.929818
# Iteration 98, loss = 0.00306612
# Validation score: 0.932052
# Iteration 99, loss = 0.00298552
# Validation score: 0.934220
# Iteration 100, loss = 0.00290748
# Validation score: 0.936482
# Iteration 101, loss = 0.00284218
# Validation score: 0.938689
# Iteration 102, loss = 0.00277307
# Validation score: 0.940943
# Iteration 103, loss = 0.00269888
# Validation score: 0.942963
# Iteration 104, loss = 0.00263569
# Validation score: 0.944756
# Iteration 105, loss = 0.00257205
# Validation score: 0.946661
# Iteration 106, loss = 0.00250934
# Validation score: 0.948385
# Iteration 107, loss = 0.00244221
# Validation score: 0.949973
# Iteration 108, loss = 0.00239521
# Validation score: 0.951797
# Iteration 109, loss = 0.00232750
# Validation score: 0.953412
# Iteration 110, loss = 0.00227220
# Validation score: 0.955006
# Iteration 111, loss = 0.00221394
# Validation score: 0.956515
# Iteration 112, loss = 0.00215677
# Validation score: 0.957874
# Iteration 113, loss = 0.00210766
# Validation score: 0.959331
# Iteration 114, loss = 0.00206033
# Validation score: 0.960825
# Iteration 115, loss = 0.00201160
# Validation score: 0.962257
# Iteration 116, loss = 0.00195773
# Validation score: 0.963585
# Iteration 117, loss = 0.00192013
# Validation score: 0.964739
# Iteration 118, loss = 0.00187544
# Validation score: 0.966113
# Iteration 119, loss = 0.00183055
# Validation score: 0.967283
# Iteration 120, loss = 0.00178371
# Validation score: 0.968408
# Iteration 121, loss = 0.00174402
# Validation score: 0.969549
# Iteration 122, loss = 0.00170812
# Validation score: 0.970553
# Iteration 123, loss = 0.00166911
# Validation score: 0.971630
# Iteration 124, loss = 0.00163238
# Validation score: 0.972634
# Iteration 125, loss = 0.00159360
# Validation score: 0.973647
# Iteration 126, loss = 0.00156272
# Validation score: 0.974643
# Iteration 127, loss = 0.00152505
# Validation score: 0.975549
# Iteration 128, loss = 0.00149558
# Validation score: 0.976498
# Iteration 129, loss = 0.00146266
# Validation score: 0.977364
# Iteration 130, loss = 0.00142927
# Validation score: 0.978243
# Iteration 131, loss = 0.00140108
# Validation score: 0.979136
# Iteration 132, loss = 0.00136907
# Validation score: 0.979961
# Iteration 133, loss = 0.00134086
# Validation score: 0.980809
# Iteration 134, loss = 0.00131195
# Validation score: 0.981599
# Iteration 135, loss = 0.00128541
# Validation score: 0.982376
# Iteration 136, loss = 0.00125912
# Validation score: 0.983097
# Iteration 137, loss = 0.00123376
# Validation score: 0.983783
# Iteration 138, loss = 0.00121078
# Validation score: 0.984412
# Iteration 139, loss = 0.00118783
# Validation score: 0.985005
# Iteration 140, loss = 0.00116774
# Validation score: 0.985574
# Iteration 141, loss = 0.00114595
# Validation score: 0.986108
# Iteration 142, loss = 0.00112777
# Validation score: 0.986674
# Iteration 143, loss = 0.00110896
# Validation score: 0.987216
# Iteration 144, loss = 0.00109090
# Validation score: 0.987742
# Iteration 145, loss = 0.00107217
# Validation score: 0.988230
# Iteration 146, loss = 0.00105422
# Validation score: 0.988683
# Iteration 147, loss = 0.00103994
# Validation score: 0.989140
# Iteration 148, loss = 0.00102307
# Validation score: 0.989546
# Iteration 149, loss = 0.00100843
# Validation score: 0.989969
# Iteration 150, loss = 0.00099358
# Validation score: 0.990362
# Iteration 151, loss = 0.00097930
# Validation score: 0.990759
# Iteration 152, loss = 0.00096647
# Validation score: 0.991135
# Iteration 153, loss = 0.00095217
# Validation score: 0.991490
# Iteration 154, loss = 0.00093986
# Validation score: 0.991838
# Iteration 155, loss = 0.00092770
# Validation score: 0.992165
# Iteration 156, loss = 0.00091673
# Validation score: 0.992485
# Iteration 157, loss = 0.00090471
# Validation score: 0.992772
# Iteration 158, loss = 0.00089477
# Validation score: 0.993074
# Iteration 159, loss = 0.00088415
# Validation score: 0.993344
# Iteration 160, loss = 0.00087420
# Validation score: 0.993614
# Iteration 161, loss = 0.00086470
# Validation score: 0.993885
# Iteration 162, loss = 0.00085501
# Validation score: 0.994123
# Iteration 163, loss = 0.00084595
# Validation score: 0.994377
# Iteration 164, loss = 0.00083720
# Validation score: 0.994610
# Iteration 165, loss = 0.00082926
# Validation score: 0.994845
# Iteration 166, loss = 0.00082051
# Validation score: 0.995068
# Iteration 167, loss = 0.00081209
# Validation score: 0.995283
# Iteration 168, loss = 0.00080404
# Validation score: 0.995491
# Iteration 169, loss = 0.00079673
# Validation score: 0.995691
# Iteration 170, loss = 0.00078898
# Validation score: 0.995887
# Iteration 171, loss = 0.00078229
# Validation score: 0.996074
# Iteration 172, loss = 0.00077488
# Validation score: 0.996264
# Iteration 173, loss = 0.00076900
# Validation score: 0.996443
# Iteration 174, loss = 0.00076221
# Validation score: 0.996609
# Iteration 175, loss = 0.00075534
# Validation score: 0.996764
# Iteration 176, loss = 0.00074971
# Validation score: 0.996921
# Iteration 177, loss = 0.00074403
# Validation score: 0.997070
# Iteration 178, loss = 0.00073876
# Validation score: 0.997220
# Iteration 179, loss = 0.00073318
# Validation score: 0.997360
# Iteration 180, loss = 0.00072793
# Validation score: 0.997490
# Iteration 181, loss = 0.00072290
# Validation score: 0.997613
# Iteration 182, loss = 0.00071822
# Validation score: 0.997733
# Iteration 183, loss = 0.00071375
# Validation score: 0.997847
# Iteration 184, loss = 0.00070960
# Validation score: 0.997957
# Iteration 185, loss = 0.00070533
# Validation score: 0.998059
# Iteration 186, loss = 0.00070138
# Validation score: 0.998155
# Iteration 187, loss = 0.00069761
# Validation score: 0.998248
# Iteration 188, loss = 0.00069388
# Validation score: 0.998337
# Iteration 189, loss = 0.00069054
# Validation score: 0.998423
# Iteration 190, loss = 0.00068706
# Validation score: 0.998503
# Iteration 191, loss = 0.00068385
# Validation score: 0.998581
# Iteration 192, loss = 0.00068076
# Validation score: 0.998655
# Iteration 193, loss = 0.00067792
# Validation score: 0.998725
# Iteration 194, loss = 0.00067512
# Validation score: 0.998789
# Iteration 195, loss = 0.00067248
# Validation score: 0.998849
# Iteration 196, loss = 0.00066993
# Validation score: 0.998906
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 33.89972241
# Validation score: -110.084909
# Iteration 2, loss = 6.37695646
# Validation score: -5.067451
# Iteration 3, loss = 0.63004666
# Validation score: -6.830469
# Iteration 4, loss = 0.81078065
# Validation score: -7.037850
# Iteration 5, loss = 0.84048176
# Validation score: -7.275724
# Iteration 6, loss = 0.81387260
# Validation score: -7.339462
# Iteration 7, loss = 0.78525526
# Validation score: -7.226247
# Iteration 8, loss = 0.76535103
# Validation score: -6.972834
# Iteration 9, loss = 0.73794507
# Validation score: -6.611508
# Iteration 10, loss = 0.70307878
# Validation score: -6.173385
# Iteration 11, loss = 0.66226730
# Validation score: -5.684015
# Iteration 12, loss = 0.61721668
# Validation score: -5.164897
# Iteration 13, loss = 0.56930757
# Validation score: -4.632362
# Iteration 14, loss = 0.52063861
# Validation score: -4.101870
# Iteration 15, loss = 0.47129008
# Validation score: -3.586738
# Iteration 16, loss = 0.42334146
# Validation score: -3.094546
# Iteration 17, loss = 0.37722132
# Validation score: -2.632785
# Iteration 18, loss = 0.33419991
# Validation score: -2.208487
# Iteration 19, loss = 0.29350774
# Validation score: -1.826263
# Iteration 20, loss = 0.25664088
# Validation score: -1.486351
# Iteration 21, loss = 0.22327816
# Validation score: -1.189477
# Iteration 22, loss = 0.19332467
# Validation score: -0.933837
# Iteration 23, loss = 0.16715391
# Validation score: -0.716661
# Iteration 24, loss = 0.14439099
# Validation score: -0.535713
# Iteration 25, loss = 0.12506473
# Validation score: -0.388621
# Iteration 26, loss = 0.10784566
# Validation score: -0.271742
# Iteration 27, loss = 0.09404459
# Validation score: -0.180469
# Iteration 28, loss = 0.08277945
# Validation score: -0.112144
# Iteration 29, loss = 0.07324700
# Validation score: -0.063621
# Iteration 30, loss = 0.06554686
# Validation score: -0.031106
# Iteration 31, loss = 0.05968969
# Validation score: -0.011428
# Iteration 32, loss = 0.05509613
# Validation score: -0.001945
# Iteration 33, loss = 0.05147283
# Validation score: -0.000151
# Iteration 34, loss = 0.04885886
# Validation score: -0.003947
# Iteration 35, loss = 0.04685553
# Validation score: -0.011652
# Iteration 36, loss = 0.04568853
# Validation score: -0.021808
# Iteration 37, loss = 0.04451283
# Validation score: -0.033122
# Iteration 38, loss = 0.04401649
# Validation score: -0.045102
# Iteration 39, loss = 0.04359325
# Validation score: -0.056853
# Iteration 40, loss = 0.04342365
# Validation score: -0.067954
# Iteration 41, loss = 0.04331132
# Validation score: -0.077895
# Iteration 42, loss = 0.04333306
# Validation score: -0.086382
# Iteration 43, loss = 0.04329999
# Validation score: -0.093269
# Iteration 44, loss = 0.04336822
# Validation score: -0.098995
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 33.80797790
# Validation score: -132.146915
# Iteration 2, loss = 5.98304678
# Validation score: -6.509351
# Iteration 3, loss = 0.60176859
# Validation score: -9.143882
# Iteration 4, loss = 0.77386569
# Validation score: -9.054666
# Iteration 5, loss = 0.81024297
# Validation score: -8.832286
# Iteration 6, loss = 0.80256315
# Validation score: -7.671469
# Iteration 7, loss = 0.75383247
# Validation score: -7.000974
# Iteration 8, loss = 0.68039157
# Validation score: -5.299742
# Iteration 9, loss = 0.54039528
# Validation score: -3.368957
# Iteration 10, loss = 0.38305955
# Validation score: -1.636680
# Iteration 11, loss = 0.22682212
# Validation score: -0.416879
# Iteration 12, loss = 0.10064135
# Validation score: 0.072298
# Iteration 13, loss = 0.05558327
# Validation score: -0.107235
# Iteration 14, loss = 0.06104731
# Validation score: -0.236518
# Iteration 15, loss = 0.05471427
# Validation score: 0.075819
# Iteration 16, loss = 0.05482275
# Validation score: -0.531633
# Iteration 17, loss = 0.07282420
# Validation score: 0.268485
# Iteration 18, loss = 0.04452011
# Validation score: 0.307055
# Iteration 19, loss = 0.03236053
# Validation score: 0.329668
# Iteration 20, loss = 0.03302197
# Validation score: 0.287711
# Iteration 21, loss = 0.03560441
# Validation score: 0.280220
# Iteration 22, loss = 0.02918844
# Validation score: 0.344485
# Iteration 23, loss = 0.02867215
# Validation score: 0.262845
# Iteration 24, loss = 0.02940267
# Validation score: 0.369493
# Iteration 25, loss = 0.02897960
# Validation score: 0.371318
# Iteration 26, loss = 0.02783504
# Validation score: 0.178452
# Iteration 27, loss = 0.03258119
# Validation score: 0.298519
# Iteration 28, loss = 0.03670823
# Validation score: 0.310540
# Iteration 29, loss = 0.02926739
# Validation score: 0.442341
# Iteration 30, loss = 0.02934607
# Validation score: 0.481607
# Iteration 31, loss = 0.02492344
# Validation score: 0.452135
# Iteration 32, loss = 0.02501421
# Validation score: 0.414478
# Iteration 33, loss = 0.03107531
# Validation score: 0.397372
# Iteration 34, loss = 0.02537816
# Validation score: 0.533940
# Iteration 35, loss = 0.02333708
# Validation score: 0.528578
# Iteration 36, loss = 0.02000151
# Validation score: 0.609430
# Iteration 37, loss = 0.01874571
# Validation score: 0.579998
# Iteration 38, loss = 0.01837574
# Validation score: 0.651725
# Iteration 39, loss = 0.01741883
# Validation score: 0.667342
# Iteration 40, loss = 0.01581954
# Validation score: 0.660309
# Iteration 41, loss = 0.01559723
# Validation score: 0.690890
# Iteration 42, loss = 0.01570851
# Validation score: 0.637338
# Iteration 43, loss = 0.01634221
# Validation score: 0.671286
# Iteration 44, loss = 0.01851482
# Validation score: 0.658841
# Iteration 45, loss = 0.01516855
# Validation score: 0.661744
# Iteration 46, loss = 0.02023883
# Validation score: 0.664369
# Iteration 47, loss = 0.01602957
# Validation score: 0.764493
# Iteration 48, loss = 0.01263366
# Validation score: 0.752688
# Iteration 49, loss = 0.01171121
# Validation score: 0.783782
# Iteration 50, loss = 0.01197363
# Validation score: 0.781622
# Iteration 51, loss = 0.01076250
# Validation score: 0.806759
# Iteration 52, loss = 0.01002274
# Validation score: 0.805040
# Iteration 53, loss = 0.00978065
# Validation score: 0.823650
# Iteration 54, loss = 0.00920901
# Validation score: 0.829220
# Iteration 55, loss = 0.00887217
# Validation score: 0.836110
# Iteration 56, loss = 0.00844792
# Validation score: 0.848616
# Iteration 57, loss = 0.00799616
# Validation score: 0.859317
# Iteration 58, loss = 0.00782634
# Validation score: 0.865434
# Iteration 59, loss = 0.00727703
# Validation score: 0.873256
# Iteration 60, loss = 0.00691566
# Validation score: 0.873483
# Iteration 61, loss = 0.00668535
# Validation score: 0.887067
# Iteration 62, loss = 0.00678212
# Validation score: 0.878544
# Iteration 63, loss = 0.00648655
# Validation score: 0.903105
# Iteration 64, loss = 0.00585636
# Validation score: 0.889085
# Iteration 65, loss = 0.00611431
# Validation score: 0.909115
# Iteration 66, loss = 0.00595221
# Validation score: 0.915573
# Iteration 67, loss = 0.00494541
# Validation score: 0.923983
# Iteration 68, loss = 0.00465869
# Validation score: 0.932940
# Iteration 69, loss = 0.00438370
# Validation score: 0.936639
# Iteration 70, loss = 0.00417482
# Validation score: 0.940685
# Iteration 71, loss = 0.00389022
# Validation score: 0.947818
# Iteration 72, loss = 0.00356202
# Validation score: 0.952261
# Iteration 73, loss = 0.00323927
# Validation score: 0.948465
# Iteration 74, loss = 0.00344386
# Validation score: 0.958912
# Iteration 75, loss = 0.00292897
# Validation score: 0.956086
# Iteration 76, loss = 0.00304517
# Validation score: 0.965831
# Iteration 77, loss = 0.00262509
# Validation score: 0.969415
# Iteration 78, loss = 0.00238168
# Validation score: 0.972306
# Iteration 79, loss = 0.00218209
# Validation score: 0.973625
# Iteration 80, loss = 0.00209868
# Validation score: 0.971952
# Iteration 81, loss = 0.00212237
# Validation score: 0.976628
# Iteration 82, loss = 0.00196001
# Validation score: 0.979109
# Iteration 83, loss = 0.00174584
# Validation score: 0.981211
# Iteration 84, loss = 0.00162790
# Validation score: 0.982547
# Iteration 85, loss = 0.00153435
# Validation score: 0.982158
# Iteration 86, loss = 0.00150503
# Validation score: 0.984704
# Iteration 87, loss = 0.00142948
# Validation score: 0.985802
# Iteration 88, loss = 0.00131308
# Validation score: 0.987452
# Iteration 89, loss = 0.00124774
# Validation score: 0.988543
# Iteration 90, loss = 0.00118948
# Validation score: 0.989276
# Iteration 91, loss = 0.00115675
# Validation score: 0.990638
# Iteration 92, loss = 0.00109615
# Validation score: 0.991461
# Iteration 93, loss = 0.00105440
# Validation score: 0.992158
# Iteration 94, loss = 0.00101977
# Validation score: 0.992722
# Iteration 95, loss = 0.00099978
# Validation score: 0.992897
# Iteration 96, loss = 0.00100607
# Validation score: 0.994140
# Iteration 97, loss = 0.00093307
# Validation score: 0.994464
# Iteration 98, loss = 0.00091947
# Validation score: 0.995096
# Iteration 99, loss = 0.00088095
# Validation score: 0.995439
# Iteration 100, loss = 0.00086218
# Validation score: 0.995917
# Iteration 101, loss = 0.00083861
# Validation score: 0.996183
# Iteration 102, loss = 0.00082533
# Validation score: 0.996631
# Iteration 103, loss = 0.00080716
# Validation score: 0.996820
# Iteration 104, loss = 0.00079844
# Validation score: 0.997210
# Iteration 105, loss = 0.00078684
# Validation score: 0.997504
# Iteration 106, loss = 0.00077347
# Validation score: 0.997753
# Iteration 107, loss = 0.00076260
# Validation score: 0.997991
# Iteration 108, loss = 0.00075506
# Validation score: 0.998092
# Iteration 109, loss = 0.00074905
# Validation score: 0.998326
# Iteration 110, loss = 0.00074978
# Validation score: 0.998255
# Iteration 111, loss = 0.00075266
# Validation score: 0.998667
# Iteration 112, loss = 0.00074407
# Validation score: 0.998917
# Iteration 113, loss = 0.00072578
# Validation score: 0.998852
# Iteration 114, loss = 0.00072688
# Validation score: 0.998936
# Iteration 115, loss = 0.00073594
# Validation score: 0.998946
# Iteration 116, loss = 0.00072988
# Validation score: 0.999315
# Iteration 117, loss = 0.00071778
# Validation score: 0.999333
# Iteration 118, loss = 0.00071167
# Validation score: 0.999450
# Iteration 119, loss = 0.00070435
# Validation score: 0.999464
# Iteration 120, loss = 0.00070461
# Validation score: 0.999280
# Iteration 121, loss = 0.00070699
# Validation score: 0.999404
# Iteration 122, loss = 0.00070937
# Validation score: 0.999335
# Iteration 123, loss = 0.00070392
# Validation score: 0.999554
# Iteration 124, loss = 0.00069853
# Validation score: 0.999542
# Iteration 125, loss = 0.00069483
# Validation score: 0.999614
# Iteration 126, loss = 0.00069104
# Validation score: 0.999658
# Iteration 127, loss = 0.00069180
# Validation score: 0.999594
# Iteration 128, loss = 0.00068942
# Validation score: 0.999674
# Iteration 129, loss = 0.00069297
# Validation score: 0.999636
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.60084112
# Validation score: -7.269482
# Iteration 2, loss = 0.40786067
# Validation score: -1.322166
# Iteration 3, loss = 0.08420568
# Validation score: -0.620515
# Iteration 4, loss = 0.13461154
# Validation score: -0.797434
# Iteration 5, loss = 0.13743829
# Validation score: 0.163299
# Iteration 6, loss = 0.05239668
# Validation score: 0.296667
# Iteration 7, loss = 0.03343354
# Validation score: -0.195113
# Iteration 8, loss = 0.05442073
# Validation score: -0.145284
# Iteration 9, loss = 0.04290460
# Validation score: 0.313865
# Iteration 10, loss = 0.01753015
# Validation score: 0.582005
# Iteration 11, loss = 0.01364902
# Validation score: 0.591545
# Iteration 12, loss = 0.02274482
# Validation score: 0.577785
# Iteration 13, loss = 0.02365619
# Validation score: 0.608109
# Iteration 14, loss = 0.01510664
# Validation score: 0.588521
# Iteration 15, loss = 0.00810462
# Validation score: 0.504819
# Iteration 16, loss = 0.00853256
# Validation score: 0.450027
# Iteration 17, loss = 0.01020705
# Validation score: 0.501808
# Iteration 18, loss = 0.00849239
# Validation score: 0.604768
# Iteration 19, loss = 0.00562871
# Validation score: 0.678490
# Iteration 20, loss = 0.00509413
# Validation score: 0.707974
# Iteration 21, loss = 0.00577677
# Validation score: 0.720882
# Iteration 22, loss = 0.00516459
# Validation score: 0.718988
# Iteration 23, loss = 0.00362203
# Validation score: 0.691064
# Iteration 24, loss = 0.00311240
# Validation score: 0.656898
# Iteration 25, loss = 0.00361112
# Validation score: 0.656606
# Iteration 26, loss = 0.00344021
# Validation score: 0.697166
# Iteration 27, loss = 0.00259003
# Validation score: 0.739370
# Iteration 28, loss = 0.00218540
# Validation score: 0.761492
# Iteration 29, loss = 0.00242085
# Validation score: 0.766134
# Iteration 30, loss = 0.00233848
# Validation score: 0.757421
# Iteration 31, loss = 0.00185677
# Validation score: 0.741757
# Iteration 32, loss = 0.00164300
# Validation score: 0.726897
# Iteration 33, loss = 0.00166440
# Validation score: 0.725143
# Iteration 34, loss = 0.00155421
# Validation score: 0.736268
# Iteration 35, loss = 0.00131971
# Validation score: 0.751054
# Iteration 36, loss = 0.00125447
# Validation score: 0.762466
# Iteration 37, loss = 0.00125211
# Validation score: 0.766493
# Iteration 38, loss = 0.00112139
# Validation score: 0.764874
# Iteration 39, loss = 0.00096023
# Validation score: 0.759858
# Iteration 40, loss = 0.00093487
# Validation score: 0.756393
# Iteration 41, loss = 0.00094744
# Validation score: 0.759816
# Iteration 42, loss = 0.00086796
# Validation score: 0.767633
# Iteration 43, loss = 0.00076913
# Validation score: 0.773215
# Iteration 44, loss = 0.00076238
# Validation score: 0.772827
# Iteration 45, loss = 0.00071981
# Validation score: 0.766618
# Iteration 46, loss = 0.00065136
# Validation score: 0.760149
# Iteration 47, loss = 0.00062506
# Validation score: 0.758116
# Iteration 48, loss = 0.00060609
# Validation score: 0.761025
# Iteration 49, loss = 0.00056148
# Validation score: 0.765437
# Iteration 50, loss = 0.00052391
# Validation score: 0.770218
# Iteration 51, loss = 0.00050101
# Validation score: 0.772257
# Iteration 52, loss = 0.00048177
# Validation score: 0.771203
# Iteration 53, loss = 0.00045579
# Validation score: 0.769497
# Iteration 54, loss = 0.00043518
# Validation score: 0.769010
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.54510301
# Validation score: -5.382664
# Iteration 2, loss = 0.38456720
# Validation score: -0.768027
# Iteration 3, loss = 0.06916243
# Validation score: 0.072682
# Iteration 4, loss = 0.14183681
# Validation score: 0.154198
# Iteration 5, loss = 0.12296533
# Validation score: 0.524424
# Iteration 6, loss = 0.03895720
# Validation score: 0.144986
# Iteration 7, loss = 0.03591956
# Validation score: -0.274387
# Iteration 8, loss = 0.05420093
# Validation score: -0.003704
# Iteration 9, loss = 0.03509320
# Validation score: 0.458787
# Iteration 10, loss = 0.01480118
# Validation score: 0.647206
# Iteration 11, loss = 0.01798458
# Validation score: 0.646805
# Iteration 12, loss = 0.02528550
# Validation score: 0.653101
# Iteration 13, loss = 0.01970054
# Validation score: 0.645724
# Iteration 14, loss = 0.01053155
# Validation score: 0.558068
# Iteration 15, loss = 0.00803510
# Validation score: 0.457153
# Iteration 16, loss = 0.01106308
# Validation score: 0.453729
# Iteration 17, loss = 0.01090212
# Validation score: 0.548541
# Iteration 18, loss = 0.00725845
# Validation score: 0.645925
# Iteration 19, loss = 0.00564726
# Validation score: 0.701886
# Iteration 20, loss = 0.00647750
# Validation score: 0.724749
# Iteration 21, loss = 0.00634867
# Validation score: 0.725362
# Iteration 22, loss = 0.00453937
# Validation score: 0.701622
# Iteration 23, loss = 0.00340458
# Validation score: 0.671600
# Iteration 24, loss = 0.00375778
# Validation score: 0.671903
# Iteration 25, loss = 0.00380587
# Validation score: 0.712744
# Iteration 26, loss = 0.00292924
# Validation score: 0.760876
# Iteration 27, loss = 0.00229206
# Validation score: 0.791537
# Iteration 28, loss = 0.00249324
# Validation score: 0.801618
# Iteration 29, loss = 0.00242467
# Validation score: 0.792515
# Iteration 30, loss = 0.00199119
# Validation score: 0.771666
# Iteration 31, loss = 0.00176769
# Validation score: 0.758880
# Iteration 32, loss = 0.00175834
# Validation score: 0.763320
# Iteration 33, loss = 0.00158254
# Validation score: 0.779030
# Iteration 34, loss = 0.00137240
# Validation score: 0.793818
# Iteration 35, loss = 0.00134188
# Validation score: 0.799891
# Iteration 36, loss = 0.00124979
# Validation score: 0.796512
# Iteration 37, loss = 0.00105686
# Validation score: 0.788459
# Iteration 38, loss = 0.00096346
# Validation score: 0.785346
# Iteration 39, loss = 0.00095031
# Validation score: 0.791501
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.54184134
# Validation score: -6.175896
# Iteration 2, loss = 0.42202083
# Validation score: -1.227798
# Iteration 3, loss = 0.07484421
# Validation score: 0.094026
# Iteration 4, loss = 0.13657924
# Validation score: 0.075740
# Iteration 5, loss = 0.13603647
# Validation score: 0.438886
# Iteration 6, loss = 0.04560068
# Validation score: 0.095636
# Iteration 7, loss = 0.03220504
# Validation score: -0.436502
# Iteration 8, loss = 0.05737699
# Validation score: -0.273510
# Iteration 9, loss = 0.04500437
# Validation score: 0.255967
# Iteration 10, loss = 0.01885551
# Validation score: 0.564880
# Iteration 11, loss = 0.01484383
# Validation score: 0.597781
# Iteration 12, loss = 0.02508831
# Validation score: 0.596944
# Iteration 13, loss = 0.02598275
# Validation score: 0.641554
# Iteration 14, loss = 0.01603435
# Validation score: 0.629387
# Iteration 15, loss = 0.00868861
# Validation score: 0.538764
# Iteration 16, loss = 0.00992272
# Validation score: 0.486705
# Iteration 17, loss = 0.01226248
# Validation score: 0.546361
# Iteration 18, loss = 0.00970071
# Validation score: 0.652513
# Iteration 19, loss = 0.00588578
# Validation score: 0.726779
# Iteration 20, loss = 0.00534486
# Validation score: 0.754065
# Iteration 21, loss = 0.00612361
# Validation score: 0.758875
# Iteration 22, loss = 0.00535834
# Validation score: 0.747023
# Iteration 23, loss = 0.00369173
# Validation score: 0.713159
# Iteration 24, loss = 0.00304964
# Validation score: 0.679948
# Iteration 25, loss = 0.00348637
# Validation score: 0.679179
# Iteration 26, loss = 0.00338101
# Validation score: 0.707699
# Iteration 27, loss = 0.00254033
# Validation score: 0.740683
# Iteration 28, loss = 0.00210524
# Validation score: 0.762976
# Iteration 29, loss = 0.00229029
# Validation score: 0.772380
# Iteration 30, loss = 0.00221166
# Validation score: 0.769385
# Iteration 31, loss = 0.00175681
# Validation score: 0.758687
# Iteration 32, loss = 0.00155427
# Validation score: 0.747622
# Iteration 33, loss = 0.00159753
# Validation score: 0.749451
# ...
# Iteration 181, loss = 0.00022026
# Validation score: 0.672420
# Iteration 182, loss = 0.00021630
# Validation score: 0.672486
# Iteration 183, loss = 0.00021088
# Validation score: 0.672803
# Iteration 184, loss = 0.00020761
# Validation score: 0.673044
# Iteration 185, loss = 0.00020555
# Validation score: 0.673061
# Iteration 186, loss = 0.00020189
# Validation score: 0.672920
# Iteration 187, loss = 0.00019623
# Validation score: 0.672538
# Iteration 188, loss = 0.00019098
# Validation score: 0.672083
# Iteration 189, loss = 0.00018826
# Validation score: 0.671697
# Iteration 190, loss = 0.00018557
# Validation score: 0.671372
# Iteration 191, loss = 0.00018146
# Validation score: 0.671220
# Iteration 192, loss = 0.00017738
# Validation score: 0.671238
# Iteration 193, loss = 0.00017329
# Validation score: 0.671518
# Iteration 194, loss = 0.00016958
# Validation score: 0.672040
# Iteration 195, loss = 0.00016714
# Validation score: 0.672683
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.47234950
# Validation score: -22.721227
# Iteration 2, loss = 0.36871917
# Validation score: -1.978276
# Iteration 3, loss = 0.08531825
# Validation score: -11.428889
# Iteration 4, loss = 0.13577631
# Validation score: -11.331960
# Iteration 5, loss = 0.11344360
# Validation score: -3.705076
# Iteration 6, loss = 0.04035747
# Validation score: -2.565009
# Iteration 7, loss = 0.04094478
# Validation score: -3.955125
# Iteration 8, loss = 0.05482604
# Validation score: -2.578298
# Iteration 9, loss = 0.03541257
# Validation score: -1.096676
# Iteration 10, loss = 0.01666658
# Validation score: -1.766115
# Iteration 11, loss = 0.01969768
# Validation score: -2.949512
# Iteration 12, loss = 0.02601486
# Validation score: -2.719925
# Iteration 13, loss = 0.02134028
# Validation score: -1.457661
# Iteration 14, loss = 0.01146366
# Validation score: -0.543852
# Iteration 15, loss = 0.00782236
# Validation score: -0.488657
# Iteration 16, loss = 0.01039680
# Validation score: -0.616728
# Iteration 17, loss = 0.01059933
# Validation score: -0.487630
# Iteration 18, loss = 0.00720217
# Validation score: -0.375860
# Iteration 19, loss = 0.00521278
# Validation score: -0.455313
# Iteration 20, loss = 0.00593445
# Validation score: -0.454196
# Iteration 21, loss = 0.00574218
# Validation score: -0.239340
# Iteration 22, loss = 0.00410921
# Validation score: -0.007751
# Iteration 23, loss = 0.00329894
# Validation score: 0.090302
# Iteration 24, loss = 0.00363435
# Validation score: 0.104874
# Iteration 25, loss = 0.00346092
# Validation score: 0.082999
# Iteration 26, loss = 0.00259248
# Validation score: 0.015887
# Iteration 27, loss = 0.00224942
# Validation score: -0.067246
# Iteration 28, loss = 0.00243407
# Validation score: -0.076354
# Iteration 29, loss = 0.00228123
# Validation score: -0.013800
# Iteration 30, loss = 0.00185205
# Validation score: 0.054121
# Iteration 31, loss = 0.00175174
# Validation score: 0.103044
# Iteration 32, loss = 0.00173005
# Validation score: 0.128564
# Iteration 33, loss = 0.00153312
# Validation score: 0.117812
# Iteration 34, loss = 0.00135834
# Validation score: 0.085837
# Iteration 35, loss = 0.00132487
# Validation score: 0.075051
# Iteration 36, loss = 0.00126372
# Validation score: 0.095930
# Iteration 37, loss = 0.00112161
# Validation score: 0.124347
# Iteration 38, loss = 0.00104182
# Validation score: 0.140394
# Iteration 39, loss = 0.00102642
# Validation score: 0.150925
# Iteration 40, loss = 0.00095320
# Validation score: 0.158212
# Iteration 41, loss = 0.00087338
# Validation score: 0.163926
# Iteration 42, loss = 0.00083887
# Validation score: 0.178480
# Iteration 43, loss = 0.00080039
# Validation score: 0.203010
# Iteration 44, loss = 0.00074775
# Validation score: 0.215236
# Iteration 45, loss = 0.00070692
# Validation score: 0.211172
# Iteration 46, loss = 0.00067056
# Validation score: 0.200511
# Iteration 47, loss = 0.00063505
# Validation score: 0.187359
# Iteration 48, loss = 0.00060806
# Validation score: 0.184253
# Iteration 49, loss = 0.00058374
# Validation score: 0.192887
# Iteration 50, loss = 0.00055650
# Validation score: 0.208567
# Iteration 51, loss = 0.00052775
# Validation score: 0.223496
# Iteration 52, loss = 0.00051047
# Validation score: 0.233783
# Iteration 53, loss = 0.00048499
# Validation score: 0.233185
# Iteration 54, loss = 0.00046686
# Validation score: 0.232033
# Iteration 55, loss = 0.00044921
# Validation score: 0.234394
# Iteration 56, loss = 0.00042836
# Validation score: 0.237419
# Iteration 57, loss = 0.00041145
# Validation score: 0.242409
# Iteration 58, loss = 0.00039706
# Validation score: 0.249682
# Iteration 59, loss = 0.00038111
# Validation score: 0.251875
# Iteration 60, loss = 0.00036597
# Validation score: 0.254986
# Iteration 61, loss = 0.00035370
# Validation score: 0.258023
# Iteration 62, loss = 0.00033967
# Validation score: 0.262179
# Iteration 63, loss = 0.00032758
# Validation score: 0.262980
# Iteration 64, loss = 0.00031621
# Validation score: 0.260444
# Iteration 65, loss = 0.00030637
# Validation score: 0.258681
# Iteration 66, loss = 0.00029418
# Validation score: 0.262504
# Iteration 67, loss = 0.00028444
# Validation score: 0.267825
# Iteration 68, loss = 0.00027501
# Validation score: 0.271151
# Iteration 69, loss = 0.00026497
# Validation score: 0.273292
# Iteration 70, loss = 0.00025673
# Validation score: 0.275022
# Iteration 71, loss = 0.00024850
# Validation score: 0.277131
# Iteration 72, loss = 0.00024100
# Validation score: 0.275426
# Iteration 73, loss = 0.00023387
# Validation score: 0.275000
# Iteration 74, loss = 0.00022586
# Validation score: 0.280320
# Iteration 75, loss = 0.00021793
# Validation score: 0.281854
# Iteration 76, loss = 0.00021080
# Validation score: 0.281624
# Iteration 77, loss = 0.00020464
# Validation score: 0.281456
# Iteration 78, loss = 0.00019793
# Validation score: 0.283675
# Iteration 79, loss = 0.00019217
# Validation score: 0.285394
# Iteration 80, loss = 0.00018687
# Validation score: 0.287940
# Iteration 81, loss = 0.00018041
# Validation score: 0.290286
# Iteration 82, loss = 0.00017533
# Validation score: 0.291393
# Iteration 83, loss = 0.00017018
# Validation score: 0.291735
# Iteration 84, loss = 0.00016520
# Validation score: 0.291173
# Iteration 85, loss = 0.00016029
# Validation score: 0.289558
# Iteration 86, loss = 0.00015644
# Validation score: 0.288712
# Iteration 87, loss = 0.00015154
# Validation score: 0.292611
# Iteration 88, loss = 0.00014694
# Validation score: 0.297090
# Iteration 89, loss = 0.00014340
# Validation score: 0.299651
# Iteration 90, loss = 0.00013940
# Validation score: 0.298951
# Iteration 91, loss = 0.00013523
# Validation score: 0.296202
# Iteration 92, loss = 0.00013297
# Validation score: 0.296252
# Iteration 93, loss = 0.00012843
# Validation score: 0.298886
# Iteration 94, loss = 0.00012590
# Validation score: 0.298210
# Iteration 95, loss = 0.00012203
# Validation score: 0.294775
# Iteration 96, loss = 0.00011861
# Validation score: 0.293556
# Iteration 97, loss = 0.00011621
# Validation score: 0.295287
# Iteration 98, loss = 0.00011310
# Validation score: 0.299524
# Iteration 99, loss = 0.00011048
# Validation score: 0.303855
# Iteration 100, loss = 0.00010727
# Validation score: 0.304493
# Iteration 101, loss = 0.00010523
# Validation score: 0.303818
# Iteration 102, loss = 0.00010274
# Validation score: 0.305951
# Iteration 103, loss = 0.00009983
# Validation score: 0.306606
# Iteration 104, loss = 0.00009760
# Validation score: 0.306135
# Iteration 105, loss = 0.00009531
# Validation score: 0.305228
# Iteration 106, loss = 0.00009322
# Validation score: 0.305979
# Iteration 107, loss = 0.00009106
# Validation score: 0.308479
# Iteration 108, loss = 0.00008881
# Validation score: 0.309897
# Iteration 109, loss = 0.00008714
# Validation score: 0.308987
# Iteration 110, loss = 0.00008536
# Validation score: 0.307305
# Iteration 111, loss = 0.00008348
# Validation score: 0.307589
# Iteration 112, loss = 0.00008165
# Validation score: 0.309661
# Iteration 113, loss = 0.00007982
# Validation score: 0.311688
# Iteration 114, loss = 0.00007856
# Validation score: 0.312137
# Iteration 115, loss = 0.00007673
# Validation score: 0.311501
# Iteration 116, loss = 0.00007525
# Validation score: 0.311546
# Iteration 117, loss = 0.00007384
# Validation score: 0.311952
# Iteration 118, loss = 0.00007207
# Validation score: 0.313742
# Iteration 119, loss = 0.00007127
# Validation score: 0.314446
# Iteration 120, loss = 0.00006984
# Validation score: 0.313650
# Iteration 121, loss = 0.00006844
# Validation score: 0.315691
# Iteration 122, loss = 0.00006719
# Validation score: 0.318074
# Iteration 123, loss = 0.00006598
# Validation score: 0.318008
# Iteration 124, loss = 0.00006518
# Validation score: 0.315987
# Iteration 125, loss = 0.00006365
# Validation score: 0.315347
# Iteration 126, loss = 0.00006271
# Validation score: 0.315533
# Iteration 127, loss = 0.00006159
# Validation score: 0.317441
# Iteration 128, loss = 0.00006052
# Validation score: 0.319540
# Iteration 129, loss = 0.00005948
# Validation score: 0.320356
# Iteration 130, loss = 0.00005868
# Validation score: 0.320554
# Iteration 131, loss = 0.00005769
# Validation score: 0.319930
# Iteration 132, loss = 0.00005669
# Validation score: 0.319172
# Iteration 133, loss = 0.00005582
# Validation score: 0.318855
# Iteration 134, loss = 0.00005498
# Validation score: 0.319357
# Iteration 135, loss = 0.00005420
# Validation score: 0.319091
# Iteration 136, loss = 0.00005344
# Validation score: 0.319294
# Iteration 137, loss = 0.00005277
# Validation score: 0.319432
# Iteration 138, loss = 0.00005204
# Validation score: 0.319679
# Iteration 139, loss = 0.00005130
# Validation score: 0.320322
# Iteration 140, loss = 0.00005059
# Validation score: 0.321470
# Iteration 141, loss = 0.00004990
# Validation score: 0.321471
# Iteration 142, loss = 0.00004915
# Validation score: 0.320409
# Iteration 143, loss = 0.00004851
# Validation score: 0.320227
# Iteration 144, loss = 0.00004797
# Validation score: 0.320998
# Iteration 145, loss = 0.00004743
# Validation score: 0.321385
# Iteration 146, loss = 0.00004687
# Validation score: 0.321540
# Iteration 147, loss = 0.00004628
# Validation score: 0.322806
# Iteration 148, loss = 0.00004569
# Validation score: 0.323664
# Iteration 149, loss = 0.00004525
# Validation score: 0.323718
# Iteration 150, loss = 0.00004477
# Validation score: 0.322872
# Iteration 151, loss = 0.00004422
# Validation score: 0.321852
# Iteration 152, loss = 0.00004391
# Validation score: 0.321664
# Iteration 153, loss = 0.00004341
# Validation score: 0.323126
# Iteration 154, loss = 0.00004310
# Validation score: 0.322978
# Iteration 155, loss = 0.00004235
# Validation score: 0.321587
# Iteration 156, loss = 0.00004214
# Validation score: 0.321734
# Iteration 157, loss = 0.00004181
# Validation score: 0.323018
# Iteration 158, loss = 0.00004119
# Validation score: 0.323629
# Iteration 159, loss = 0.00004081
# Validation score: 0.324022
# Iteration 160, loss = 0.00004040
# Validation score: 0.323955
# Iteration 161, loss = 0.00004013
# Validation score: 0.324598
# Iteration 162, loss = 0.00003967
# Validation score: 0.325142
# Iteration 163, loss = 0.00003945
# Validation score: 0.324470
# Iteration 164, loss = 0.00003902
# Validation score: 0.323684
# Iteration 165, loss = 0.00003874
# Validation score: 0.324868
# Iteration 166, loss = 0.00003830
# Validation score: 0.325668
# Iteration 167, loss = 0.00003803
# Validation score: 0.325737
# Iteration 168, loss = 0.00003771
# Validation score: 0.325470
# Iteration 169, loss = 0.00003736
# Validation score: 0.324428
# Iteration 170, loss = 0.00003717
# Validation score: 0.324430
# Iteration 171, loss = 0.00003683
# Validation score: 0.324745
# Iteration 172, loss = 0.00003653
# Validation score: 0.325574
# Iteration 173, loss = 0.00003624
# Validation score: 0.326070
# Iteration 174, loss = 0.00003600
# Validation score: 0.326338
# Iteration 175, loss = 0.00003576
# Validation score: 0.326619
# Iteration 176, loss = 0.00003551
# Validation score: 0.325711
# Iteration 177, loss = 0.00003525
# Validation score: 0.324781
# Iteration 178, loss = 0.00003508
# Validation score: 0.324681
# Iteration 179, loss = 0.00003480
# Validation score: 0.325913
# Iteration 180, loss = 0.00003460
# Validation score: 0.326832
# Iteration 181, loss = 0.00003440
# Validation score: 0.326689
# Iteration 182, loss = 0.00003415
# Validation score: 0.326704
# Iteration 183, loss = 0.00003399
# Validation score: 0.327100
# Iteration 184, loss = 0.00003377
# Validation score: 0.327936
# Iteration 185, loss = 0.00003360
# Validation score: 0.327670
# Iteration 186, loss = 0.00003340
# Validation score: 0.327301
# Iteration 187, loss = 0.00003320
# Validation score: 0.327507
# Iteration 188, loss = 0.00003301
# Validation score: 0.327690
# Iteration 189, loss = 0.00003288
# Validation score: 0.327637
# Iteration 190, loss = 0.00003270
# Validation score: 0.327361
# Iteration 191, loss = 0.00003256
# Validation score: 0.327715
# Iteration 192, loss = 0.00003238
# Validation score: 0.328683
# Iteration 193, loss = 0.00003224
# Validation score: 0.328409
# Iteration 194, loss = 0.00003211
# Validation score: 0.327878
# Iteration 195, loss = 0.00003198
# Validation score: 0.328692
# Iteration 196, loss = 0.00003178
# Validation score: 0.329736
# Iteration 197, loss = 0.00003167
# Validation score: 0.329087
# Iteration 198, loss = 0.00003151
# Validation score: 0.328096
# Iteration 199, loss = 0.00003143
# Validation score: 0.328322
# Iteration 200, loss = 0.00003126
# Validation score: 0.328509
# Iteration 201, loss = 0.00003116
# Validation score: 0.328272
# Iteration 202, loss = 0.00003104
# Validation score: 0.328815
# Iteration 203, loss = 0.00003089
# Validation score: 0.329886
# Iteration 204, loss = 0.00003082
# Validation score: 0.329879
# Iteration 205, loss = 0.00003065
# Validation score: 0.328898
# Iteration 206, loss = 0.00003058
# Validation score: 0.329095
# Iteration 207, loss = 0.00003044
# Validation score: 0.330048
# Iteration 208, loss = 0.00003034
# Validation score: 0.330106
# Iteration 209, loss = 0.00003024
# Validation score: 0.330063
# Iteration 210, loss = 0.00003013
# Validation score: 0.330499
# Iteration 211, loss = 0.00003004
# Validation score: 0.330834
# Iteration 212, loss = 0.00002996
# Validation score: 0.330864
# Iteration 213, loss = 0.00002986
# Validation score: 0.330551
# Iteration 214, loss = 0.00002979
# Validation score: 0.330718
# Iteration 215, loss = 0.00002968
# Validation score: 0.330786
# Iteration 216, loss = 0.00002959
# Validation score: 0.330677
# Iteration 217, loss = 0.00002951
# Validation score: 0.330709
# Iteration 218, loss = 0.00002944
# Validation score: 0.331123
# Iteration 219, loss = 0.00002937
# Validation score: 0.331813
# Iteration 220, loss = 0.00002929
# Validation score: 0.331651
# Iteration 221, loss = 0.00002920
# Validation score: 0.331426
# Iteration 222, loss = 0.00002914
# Validation score: 0.331658
# Iteration 223, loss = 0.00002906
# Validation score: 0.331627
# Iteration 224, loss = 0.00002901
# Validation score: 0.330876
# Iteration 225, loss = 0.00002895
# Validation score: 0.330665
# Iteration 226, loss = 0.00002887
# Validation score: 0.331738
# Iteration 227, loss = 0.00002882
# Validation score: 0.332067
# Iteration 228, loss = 0.00002875
# Validation score: 0.331286
# Iteration 229, loss = 0.00002869
# Validation score: 0.331380
# Iteration 230, loss = 0.00002862
# Validation score: 0.331957
# Iteration 231, loss = 0.00002858
# Validation score: 0.332245
# Iteration 232, loss = 0.00002851
# Validation score: 0.332260
# Iteration 233, loss = 0.00002847
# Validation score: 0.332175
# Iteration 234, loss = 0.00002841
# Validation score: 0.331934
# Iteration 235, loss = 0.00002836
# Validation score: 0.332061
# Iteration 236, loss = 0.00002833
# Validation score: 0.332510
# Iteration 237, loss = 0.00002827
# Validation score: 0.333006
# Iteration 238, loss = 0.00002825
# Validation score: 0.332736
# Iteration 239, loss = 0.00002818
# Validation score: 0.332576
# Iteration 240, loss = 0.00002813
# Validation score: 0.332723
# Iteration 241, loss = 0.00002809
# Validation score: 0.332670
# Iteration 242, loss = 0.00002804
# Validation score: 0.332634
# Iteration 243, loss = 0.00002801
# Validation score: 0.332627
# Iteration 244, loss = 0.00002796
# Validation score: 0.332663
# Iteration 245, loss = 0.00002793
# Validation score: 0.332464
# Iteration 246, loss = 0.00002789
# Validation score: 0.332146
# Iteration 247, loss = 0.00002786
# Validation score: 0.332288
# Iteration 248, loss = 0.00002783
# Validation score: 0.332559
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Best parameters: {'ann__learning_rate_init': 0.01}
# Best cross-validation score: -0.02301662979088932

# %%
# XG Boost
from xgboost import XGBRegressor

# Load the dataset
data = pd.read_csv('./train_data_problem2.csv', delimiter=',')

X = data.drop('school_binary', axis=1)
y = data['school_binary']

# Identifying categorical and numerical columns for preprocessing
categorical_columns = X.select_dtypes(include=['object', 'category']).columns
numerical_columns = X.select_dtypes(include=['int', 'float']).columns

# Creating a preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'), categorical_columns),
        ('scaler', StandardScaler(), numerical_columns)
    ],
    remainder='passthrough'
)

# Creating a modeling pipeline with XGBoost
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('xgb', XGBRegressor(objective='reg:squarederror', random_state=42))
])

# If you want to fine-tune hyperparameters, define a parameter grid
param_grid = {
    'xgb__learning_rate': [0.01, 0.1, 0.2, 0.3, 0.4],
}

# Setting up GridSearchCV for hyperparameter tuning (optional)
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fitting the model
grid_search.fit(X, y)

# Printing the best parameters and cross-validation score
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Best parameters: {'xgb__learning_rate': 0.4}
# Best cross-validation score: -1.6095606377774851e-09
